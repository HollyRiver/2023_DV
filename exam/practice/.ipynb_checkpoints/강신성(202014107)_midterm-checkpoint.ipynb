# %% [markdown]
# # 2021년 2학기 데이터시각화 중간고사

# %%
# hide
# !pip install opencv-python
import matplotlib.pyplot as plt 
import seaborn as sns 
from plotnine import * 
import cv2 
import numpy as np 
import pandas as pd
# Out:
# WARNING: Ignoring invalid distribution -yarrow (c:\users\hollyriver\anaconda3\envs\py\lib\site-packages)
# WARNING: Ignoring invalid distribution -yarrow (c:\users\hollyriver\anaconda3\envs\py\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.
# ...

# %% [markdown]
# ### `1`. 다음은 이미지와 대응하는 히스토그램을 나타낸것이다. 이미지와 히스토그램을 올바르게 짝지어라. (5점)

# %% [markdown]
# - 예시 a-c, b-d

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG1.png?raw=true)

# %% [markdown]
# > 답 : a-c, b-d

# %% [markdown]
# ### `2`. 주어진 자료를 바탕으로 예시와 같은 시각화를 구현하라. (5점)

# %% [markdown]
# **자료**
#
# ```python
# x=[1,2,3,4]
# y=[1,2,4,3]
# ```

# %% [markdown]
# **시각화예시**

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG2.png?raw=true)

# %% [markdown]
# > 답

# %%
x=[1,2,3,4]
y=[1,2,4,3]

fig, ((ax1, ax2),(ax3, ax4)) =  plt.subplots(2,2, figsize = (5, 3))
ax1.plot(y, ':ob')
ax2.plot(y, 'Xr')
ax3.plot(y, 'xk')
ax4.plot(y, '--.', color = 'magenta')
fig.tight_layout()

# %% [markdown]
# ### `3`. 아래는 앤스콤의 플랏이다. 옳게 해석한 사람을 모두 고르라 (5점)

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG3.png?raw=true)

# %% [markdown]
# (하니) 그림 (a)-(d)는 모두 양의 상관계수를 가진다.
#
# (나애리) 그림 (b)는 산점도가 직선이 아니라 곡선의 모양을 띄고 있으므로 상관계수는 0이다.
#
# (홍두깨) 그림 (c)에서 상단의 이상치를 제외하면 상관계수는 1이다.
#
# (고은애) 그림 (d)의 우측 이상치의 값을 적절하게 바꾸면 (d)의 상관계수를 음수로 만드는 것이 가능하다.
#
# (이창수) 그림 (c)역시 상단의 이상치 값을 적절하게 바꾸면 (c)의 상관계수를 음수로 만드는 것이 가능하다.

# %% [markdown]
# > 답 : (하니), (홍두깨), (고은애), (이창수)

# %% [markdown]
# ### `4`. 다음은 아이스크림 소비량과 소아마비의 관계를 그린 산점도이다. 이때 색깔은 온도가 비슷한 관측치로 그룹핑되었다. 옳은 해석을 모두 골라라. (10점)

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG4.png?raw=true)

# %% [markdown]
# (하니) 아이스크림과 소아마비는 양의 상관관계에 있다.
#
# (나애리) 상관계수의 값이 1에 가까울수록 아이스크림과 소아마비의 인과성이 명확하다고 볼 수 있다.
#
# (홍두깨) 비슷한 온도를 가진 관측치에서는 아이스크림과 소아마비의 상관계수가 0에 가깝다.
#
# (고은애) 온도를 통제하였을 경우 아이스크림과 소아마비의 상관계수가 0이므로 둘 사이의 인과성이 있다고 보긴 어렵다.

# %% [markdown]
# > 답 : (하니), (홍두깨), (고은애)

# %% [markdown]
# ### `5`. FIFA22 (100점)

# %% [markdown]
# 아래의 코드를 활용하여 FIFA22의 자료를 불러온뒤 물음에 답하라.

# %% [markdown]
# ```python
# df=pd.read_csv('https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/2021-10-25-FIFA22_official_data.csv')
# ```

# %% [markdown]
# #### (a) `Loaned From`,`Marking` 열을 선택하는 코드를 작성하고 값을 확인하라.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/2021-10-25-FIFA22_official_data.csv')

# %%
df[['Loaned From', 'Marking']]
# Out:
#       Loaned From  Marking
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             NaN      NaN
# ...           ...      ...
# 16705         NaN      5.0
# 16706         NaN      NaN
# 16707         NaN      NaN
# 16708         NaN      NaN
# 16709         NaN     15.0
#
# [16710 rows x 2 columns]

# %% [markdown]
# #### (b) 기존의 데이터프레임에서 `Loaned From`, `Marking`열을 제외하는 코드를 작성하라.

# %%
df.drop(['Loaned From', 'Marking'], axis = 1)
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16705  240558    18 L. Clayton   17
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
# 16709  178453    07 A. Censori   17
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %% [markdown]
# #### (c) (b)의 결과에 `.dropna()`를 사용하여 결측치를 제거하는 코드를 작성하라. 몇개의 결측치가 제거되었는가?

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True)  ## 인덱스가 섞였으므로 초기화
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 14393  259718      F. Gebhardt   19
# 14394  251433          B. Voll   20
# 14395  262846         �. Dobre   20
# 14396  241317   21 Xue Qinghao   19
# 14397  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %%
print(df.drop(['Loaned From', 'Marking'], axis = 1).shape[0], df.drop(['Loaned From', 'Marking'], axis = 1).dropna().shape[0])
print(df.drop(['Loaned From', 'Marking'], axis = 1).shape[0] - df.drop(['Loaned From', 'Marking'], axis = 1).dropna().shape[0])
# Out:
# 16710 14398
# 2312

# %% [markdown]
# > 행의 개수가 2312개만큼 줄었으므로 그만큼 결측치를 제거하였다.

# %% [markdown]
# #### (d) (c)의 결과에 아래의 코드를 활용하여 `Wage`의 값을 적절하게 변환하라.
#
# ```python
# ### 코드1
# def convert_currency(value):
#     floatvalue = 0.0
#     strvalue=""
#     if "M" in value:
#         strvalue=value.replace("M","").replace("€","")
#         floatvalue=float(float(strvalue)*1000000)
#     elif "K" in value:
#         strvalue=value.replace("K","").replace("€","")
#         floatvalue=float(float(strvalue)*1000)
#     else:
#         floatvalue=value.replace("€","")
#     return floatvalue
# ```
# - 코드출처: https://www.kaggle.com/talhademirezen/cost-effective-youth-players-fifa22

# %%
def convert_currency(value):
    floatvalue = 0.0
    strvalue=""
    if "M" in value:
        strvalue=value.replace("M","").replace("€","")
        floatvalue=float(float(strvalue)*1000000)
    elif "K" in value:
        strvalue=value.replace("K","").replace("€","")
        floatvalue=float(float(strvalue)*1000)
    else:
        floatvalue=value.replace("€","")
    return floatvalue

## 문자열 유로를 없애주고, M과 K를 각각 해당하는 실수값으로 곱해주는 함수인 것 같다.

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).Wage
# Out:
# 0        €250K
# 1        €140K
# 2        €135K
# 3        €350K
# 4         €45K
#          ...
# 14393     €650
# 14394     €950
# 14395     €550
# 14396     €700
# 14397     €500
# Name: Wage, Length: 14398, dtype: object

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).Wage.apply(convert_currency)
# Out:
# 0        250000.0
# 1        140000.0
# 2        135000.0
# 3        350000.0
# 4         45000.0
#            ...
# 14393         650
# 14394         950
# 14395         550
# 14396         700
# 14397         500
# Name: Wage, Length: 14398, dtype: object

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 14393  259718      F. Gebhardt   19
# 14394  251433          B. Voll   20
# 14395  262846         �. Dobre   20
# 14396  241317   21 Xue Qinghao   19
# 14397  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# ...

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency)).Wage
# Out:
# 0        250000.0
# 1        140000.0
# 2        135000.0
# 3        350000.0
# 4         45000.0
#            ...
# 14393         650
# 14394         950
# 14395         550
# 14396         700
# 14397         500
# Name: Wage, Length: 14398, dtype: object

# %% [markdown]
# > Wage열에 잘 입력됨

# %% [markdown]
# #### (e) 아래의 세부사항에 맞춰서 `Best Position`에 따른 시장가치(`Value`)의 평균을 barplot을 이용하여 시각화 하라.

# %% [markdown]
# - x축을 `Best Position`으로 하고 y축은 `Value`의 평균으로 할 것
# - `Value`가 가장 높은 3개의 포지션을 다른색으로 하이라이팅 할 것

# %% [markdown]
# ***시각화예시***

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG5_1.png?raw=true)

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))['Best Position']
# Out:
# 0        CAM
# 1         CM
# 2         ST
# 3         CM
# 4         LB
#         ...
# 14393     GK
# 14394     GK
# 14395     GK
# 14396     GK
# 14397     GK
# Name: Best Position, Length: 14398, dtype: object

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.loc[:, ['Best Position', 'Value']]
# Out:
#       Best Position    Value
# 0               CAM  €107.5M
# 1                CM     €93M
# 2                ST   €44.5M
# 3                CM  €125.5M
# 4                LB     €37M
# ...             ...      ...
# 14393            GK    €170K
# 14394            GK    €375K
# 14395            GK    €180K
# 14396            GK    €100K
# 14397            GK    €110K
#
# [14398 rows x 2 columns]

# %% [markdown]
# > Value또한 변환이 필요할듯, 이것은 위의 함수를 사용한다.

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.loc[:, ['Best Position', 'Value']].assign(Value = lambda _df : _df.Value.apply(convert_currency))
# Out:
#       Best Position        Value
# 0               CAM  107500000.0
# 1                CM   93000000.0
# 2                ST   44500000.0
# 3                CM  125500000.0
# 4                LB   37000000.0
# ...             ...          ...
# 14393            GK     170000.0
# 14394            GK     375000.0
# 14395            GK     180000.0
# 14396            GK     100000.0
# 14397            GK     110000.0
#
# [14398 rows x 2 columns]

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.loc[:, ['Best Position', 'Value']].assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.pivot_table(index = 'Best Position', values = 'Value', aggfunc = 'mean').reset_index()
# Out:
#    Best Position         Value
# 0            CAM  4.356162e+06
# 1             CB  3.038834e+06
# 2            CDM  3.539740e+06
# 3             CF  9.122222e+06
# 4             CM  5.630414e+06
# 5             GK  2.703686e+06
# 6             LB  3.051887e+06
# 7             LM  3.439977e+06
# 8             LW  6.443137e+06
# 9            LWB  3.451340e+06
# 10            RB  3.203283e+06
# 11            RM  2.550153e+06
# 12            RW  3.977832e+06
# 13           RWB  3.023522e+06
# 14            ST  3.295080e+06

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.loc[:, ['Best Position', 'Value']].assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.pivot_table(index = 'Best Position', values = 'Value', aggfunc = 'mean').reset_index()\
.sort_values(by = 'Value', ascending = False).reset_index(drop = True).reset_index()\
.rename({'index' : 'Highlight'}, axis = 1)\
.assign(Highlight = lambda _df : _df.Highlight < 3.0)
# Out:
#     Highlight Best Position         Value
# 0        True            CF  9.122222e+06
# 1        True            LW  6.443137e+06
# 2        True            CM  5.630414e+06
# 3       False           CAM  4.356162e+06
# 4       False            RW  3.977832e+06
# 5       False           CDM  3.539740e+06
# 6       False           LWB  3.451340e+06
# 7       False            LM  3.439977e+06
# 8       False            ST  3.295080e+06
# 9       False            RB  3.203283e+06
# 10      False            LB  3.051887e+06
# 11      False            CB  3.038834e+06
# 12      False           RWB  3.023522e+06
# 13      False            GK  2.703686e+06
# 14      False            RM  2.550153e+06

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.loc[:, ['Best Position', 'Value']].assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.pivot_table(index = 'Best Position', values = 'Value', aggfunc = 'mean').reset_index()\
.sort_values(by = 'Value', ascending = False).reset_index(drop = True).reset_index()\
.rename({'index' : 'Highlight', 'Value' : 'mean(Value)'}, axis = 1)\
.assign(Highlight = lambda _df : _df.Highlight < 3.0)\
.sort_values(by = 'Best Position').reset_index(drop = True)
# Out:
#     Highlight Best Position   mean(Value)
# 0       False           CAM  4.356162e+06
# 1       False            CB  3.038834e+06
# 2       False           CDM  3.539740e+06
# 3        True            CF  9.122222e+06
# 4        True            CM  5.630414e+06
# 5       False            GK  2.703686e+06
# 6       False            LB  3.051887e+06
# 7       False            LM  3.439977e+06
# 8        True            LW  6.443137e+06
# 9       False           LWB  3.451340e+06
# 10      False            RB  3.203283e+06
# 11      False            RM  2.550153e+06
# 12      False            RW  3.977832e+06
# 13      False           RWB  3.023522e+06
# 14      False            ST  3.295080e+06

# %%
tidydata = df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.loc[:, ['Best Position', 'Value']].assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.pivot_table(index = 'Best Position', values = 'Value', aggfunc = 'mean').reset_index()\
.sort_values(by = 'Value', ascending = False).reset_index(drop = True).reset_index()\
.rename({'index' : 'Highlight', 'Value' : 'mean(Value)'}, axis = 1)\
.assign(Highlight = lambda _df : _df.Highlight < 3.0)\
.sort_values(by = 'Best Position').reset_index(drop = True)

# %%
fig = ggplot(tidydata)
bar = geom_col(aes(x = 'Best Position', y = 'mean(Value)', fill = 'Highlight'))

fig + bar
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# #### (f) 아래의 세부사항에 맞추어 (`Dribbling`,`SlidingTackle`)의 산점도를 그려라.

# %% [markdown]
# ***세부사항***
#
# (i) `Best Position`의 값을 바탕으로 면분할을 하라.
#
# (ii) `Age`를 색으로 표현하라.
#
# (iii) 산점도의 투명도는 `alpha=0.5`로 `size=0.5`로 설정할 것.

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG5_2.png?raw=true)

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.loc[:, ['Dribbling', 'SlidingTackle', 'Best Position', 'Age']]
# Out:
#        Dribbling  SlidingTackle Best Position  Age
# 0           83.0           65.0           CAM   26
# 1           84.0           77.0            CM   26
# 2           83.0           38.0            ST   34
# 3           88.0           53.0            CM   30
# 4           87.0           82.0            LB   29
# ...          ...            ...           ...  ...
# 14393       12.0           10.0            GK   19
# 14394       11.0           10.0            GK   20
# 14395        6.0           12.0            GK   20
# 14396        8.0            9.0            GK   19
# 14397       10.0           13.0            GK   18
#
# [14398 rows x 4 columns]

# %%
tidydata = df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.loc[:, ['Dribbling', 'SlidingTackle', 'Best Position', 'Age']]

# %%
fig = ggplot(tidydata)
point = geom_point(aes(x = 'Dribbling', y = 'SlidingTackle', color = 'Age'), alpha = 0.5, size = 0.5)

fig + point + facet_wrap('Best Position')
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# #### (g) (f)의 그림을 올바르게 해석한 사람은?

# %% [markdown]
# (하니) 포지션 `GK`에 있는 선수는 `Dribbling`, `SlidingTackle` 값이 다른포지션대비 상대적으로 낮다.
#
# (나애리) 모든 포지션에서 `Dribbling`, `SlidingTackle`은 서로 독립이라 볼 수 있다.
#
# (홍두깨) 포지션 `CAM`은 나이와 `Dribbling` 사이에 양의 상관관계에 있다.
#
# (고은애) 포지션 `CB`은 나이와 `Dribbling` 사이에 상관계수가 거의 0이다.

# %% [markdown]
# > (하니), (홍두깨)

# %%
temp = tidydata.loc[tidydata['Best Position'] == 'CB']

np.corrcoef(temp.Age, temp.Dribbling)
# Out:
# array([[1.        , 0.19182318],
#        [0.19182318, 1.        ]])

# %%
temp2 = tidydata.loc[tidydata['Best Position'] == 'CAM']

np.corrcoef(temp2.Age, temp2.Dribbling)
# Out:
# array([[1.        , 0.40285982],
#        [0.40285982, 1.        ]])

# %% [markdown]
# #### (h) `Best Position`이 "CAM" 혹은 "CM"인 플레이어만 골라서 (`Dribbling`,`SlidingTackle`)의 산점도를 그려라.

# %% [markdown]
# ***세부사항***
#
# - x축: Dribbling, y축: SlidingTackle 로 설정
# - Value에 따라 점의 크기를 다르게 설정
# - 나이에 따라 색깔을 다르게 설정

# %% [markdown]
# ***시각화예시***

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG5_3.png?raw=true)

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.loc[:, ['Dribbling', 'SlidingTackle', 'Best Position', 'Age', 'Value']]
# Out:
#        Dribbling  SlidingTackle Best Position  Age        Value
# 0           83.0           65.0           CAM   26  107500000.0
# 1           84.0           77.0            CM   26   93000000.0
# 2           83.0           38.0            ST   34   44500000.0
# 3           88.0           53.0            CM   30  125500000.0
# 4           87.0           82.0            LB   29   37000000.0
# ...          ...            ...           ...  ...          ...
# 14393       12.0           10.0            GK   19     170000.0
# 14394       11.0           10.0            GK   20     375000.0
# 14395        6.0           12.0            GK   20     180000.0
# 14396        8.0            9.0            GK   19     100000.0
# 14397       10.0           13.0            GK   18     110000.0
#
# [14398 rows x 5 columns]

# %%
df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.loc[:, ['Dribbling', 'SlidingTackle', 'Best Position', 'Age', 'Value']]\
.loc[lambda _df : (_df['Best Position'] == 'CAM') | (_df['Best Position'] == 'CM')]
# Out:
#        Dribbling  SlidingTackle Best Position  Age        Value
# 0           83.0           65.0           CAM   26  107500000.0
# 1           84.0           77.0            CM   26   93000000.0
# 3           88.0           53.0            CM   30  125500000.0
# 6           82.0           75.0            CM   32   28500000.0
# 7           85.0           70.0            CM   30   40500000.0
# ...          ...            ...           ...  ...          ...
# 12905       52.0           41.0           CAM   19     120000.0
# 12968       50.0           27.0           CAM   20     100000.0
# 13057       58.0           14.0           CAM   20     120000.0
# 13090       54.0           14.0           CAM   19     130000.0
# 13115       40.0           29.0           CAM   20     110000.0
#
# [2740 rows x 5 columns]

# %%
tidydata = df.drop(['Loaned From', 'Marking'], axis = 1).dropna().reset_index(drop = True).assign(Wage = lambda _df : _df.Wage.apply(convert_currency))\
.assign(Value = lambda _df : _df.Value.apply(convert_currency))\
.loc[:, ['Dribbling', 'SlidingTackle', 'Best Position', 'Age', 'Value']]\
.loc[lambda _df : (_df['Best Position'] == 'CAM') | (_df['Best Position'] == 'CB')]

# %%
fig = ggplot(tidydata)
point = geom_point(aes(x = 'Dribbling', y = 'SlidingTackle', color = 'Age', size = 'Value'), alpha = 0.5)

fig + point + facet_wrap('Best Position')
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# #### (i) 그림 (h)를 올바르게 해석한것을 모두 고르라.

# %% [markdown]
# (하니) `AGE`와 `Value`는 양의 상관관계에 있다.
#
# (나애리) 따라서 축구선수는 `AGE`가 증가함 따라 `Value`가 올라가는 것을 알 수 있다. 즉 `AGE`와 `Value`사이에는 인과성이 있다.
#
# (홍두깨) 포지션 `CAM`은 `Dribbiling` 능력과 `Value`가 양의 상관관계에 있어보인다.
#
# (고은애) 반면에 포지션 `CB`는 `Dribbling` 능력보다는 `SlidingTackle`이 `Value`와 양의 상관관계에 있다고 볼 수 있다.

# %% [markdown]
# > 답 : (홍두깨), (고은애)  ## 하니도 맞다고 합니다.

# %%
np.corrcoef(tidydata.Age, tidydata.Value)
# Out:
# array([[1.       , 0.0171834],
#        [0.0171834, 1.       ]])

# %% [markdown]
# ### `6`. 하니의 산책경로 (40점)

# %% [markdown]
# 공원에서 뛰는것을 좋아하는 강아지 하니가 있다. 아래는 강아지 하니가 주인과 함께 공원을 산책한 경로이다. 산책코스는 아래와 같이 집에서 공원으로 가는 A코스와 공원에서 집으로 오는 B코스로 나누어진다.
#
# `-` A코스: 집 $\to$ 카페 $\to$ 초등학교 정문  $\to$ 공원
#
# `-` B코스: 공원 $\to$ 초등학교 후문 $\to$ 동물병원 $\to$ 집
#
# 각 위치의 좌표는 아래와 같다.
#
# - 집: (0,0)
# - 카페: (1,2)
# - 초등학교 정문: (4,3)
# - 공원: (5,5)
# - 초등학교 후문: (4.1,3)
# - 동물병원: (1,0.5)
#
# 집에서 출발시에 하니의 체력은 100이며, 각 중간지점에서 하니의 체력은 이동거리에 비례하여 감소한다고 하자. 예를들어 A코스-카페에서 하니의 체력은 아래와 같이 계산할 수 있다.
#
# - $100- \sqrt{1^2+2^2}$
#
# 또한 하니는 공원정문에서 달리기를 시작하였고 이후에 70의 체력을 소진한뒤 공원후문에 도착하였다고 하자. (즉 공원정문에서하니의 체력이 $x$ 라면 공원후문에서 하니의 체력은 $x-60$ 이다.)
#
# 하니의 이동경로에 따른 체력의 변화를 시각화 하라.

# %% [markdown]
# **시각화예시**

# %% [markdown]
# ![](https://github.com/guebin/2021DV/blob/master/_notebooks/mid_FIG6.png?raw=true)

# %%
A_x = [0, 1, 4, 5]
A_y = [0, 2, 3, 5]

B_x = [5, 4.1, 1, 0]
B_y = [5, 3, 0.5, 0]

# %%
plt.plot(A_x, A_y)
plt.plot(B_x, B_y)

# %%
np.concatenate([np.repeat('A', 4), np.repeat('B', 4)])
# Out:
# array(['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B'], dtype='<U1')

# %%
['A']*4+['B']*4
# Out:
# ['A', 'A', 'A', 'A', 'B', 'B', 'B', 'B']

# %%
df = pd.DataFrame({'X' : np.concatenate([A_x, B_x]), 'y' : np.concatenate([A_y, B_y]), 'course' : np.concatenate([np.repeat('A', 4), np.repeat('B', 4)])})
df
# Out:
#      X    y course
# 0  0.0  0.0      A
# 1  1.0  2.0      A
# 2  4.0  3.0      A
# 3  5.0  5.0      A
# 4  5.0  5.0      B
# 5  4.1  3.0      B
# 6  1.0  0.5      B
# 7  0.0  0.0      B

# %%
df.drop('course', axis = 1)
# Out:
#      X    y
# 0  0.0  0.0
# 1  1.0  2.0
# 2  4.0  3.0
# 3  5.0  5.0
# 4  5.0  5.0
# 5  4.1  3.0
# 6  1.0  0.5
# 7  0.0  0.0

# %%
dist = [(df.X[i], df.y[i]) for i in range(8)]
dist
# Out:
# [(0.0, 0.0),
#  (1.0, 2.0),
#  (4.0, 3.0),
#  (5.0, 5.0),
#  (5.0, 5.0),
#  (4.1, 3.0),
#  (1.0, 0.5),
#  (0.0, 0.0)]

# %%
dist[1][1]
# Out:
# 2.0

# %%
[np.sqrt((dist[i][0] - dist[i-1][0])**2 + (dist[i][1] - dist[i-1][1])**2) if i != 0 else 0.0 for i in range(8)]
# Out:
# [0.0,
#  2.23606797749979,
#  3.1622776601683795,
#  2.23606797749979,
#  0.0,
#  2.193171219946131,
#  3.982461550347975,
#  1.118033988749895]

# %% [markdown]
# > 이동한 거리

# %%
df.assign(Lost_stamina = [np.sqrt((dist[i][0] - dist[i-1][0])**2 + (dist[i][1] - dist[i-1][1])**2) if i != 0 else 0.0 for i in range(8)])
# Out:
#      X    y course  Lost_stamina
# 0  0.0  0.0      A      0.000000
# 1  1.0  2.0      A      2.236068
# 2  4.0  3.0      A      3.162278
# 3  5.0  5.0      A      2.236068
# 4  5.0  5.0      B      0.000000
# 5  4.1  3.0      B      2.193171
# 6  1.0  0.5      B      3.982462
# 7  0.0  0.0      B      1.118034

# %%
df.assign(Lost_stamina = [np.sqrt((dist[i][0] - dist[i-1][0])**2 + (dist[i][1] - dist[i-1][1])**2) if i != 0 else 0.0 for i in range(8)])\
.Lost_stamina
# Out:
# 0    0.000000
# 1    2.236068
# 2    3.162278
# 3    2.236068
# 4    0.000000
# 5    2.193171
# 6    3.982462
# 7    1.118034
# Name: Lost_stamina, dtype: float64

# %%
lst = [np.sqrt((dist[i][0] - dist[i-1][0])**2 + (dist[i][1] - dist[i-1][1])**2) if i != 0 else 0.0 for i in range(8)]
stamina = []
curr_stamina = 100

for i in range(8) :
    curr_stamina -= lst[i]
    if i != 4:
        stamina.append(curr_stamina)
    else :
        curr_stamina -= 70
        stamina.append(curr_stamina)

stamina
# Out:
# [100.0,
#  97.76393202250021,
#  94.60165436233183,
#  92.36558638483204,
#  22.365586384832042,
#  20.172415164885912,
#  16.189953614537938,
#  15.071919625788043]

# %%
df.assign(stamina = stamina)
# Out:
#      X    y course     stamina
# 0  0.0  0.0      A  100.000000
# 1  1.0  2.0      A   97.763932
# 2  4.0  3.0      A   94.601654
# 3  5.0  5.0      A   92.365586
# 4  5.0  5.0      B   22.365586
# 5  4.1  3.0      B   20.172415
# 6  1.0  0.5      B   16.189954
# 7  0.0  0.0      B   15.071920

# %%
fig = ggplot(df)
bar = geom_line(aes(x = 'X', y = 'y', size = 'stamina', color = 'course'), alpha = 0.5)
point = geom_point(aes(x = 'X', y = 'y'))

fig + bar + point
# Out:
# <Figure Size: (640 x 480)>

# %%
x = [0, 1, 4, 5, 5, 4.1, 1, 0]
y = [0, 2, 3, 5, 5, 3, 0.5, 0]

course = ['A']*4+['B']*4

pd.DataFrame({'x':x, 'y':y, 'course' : course})
# Out:
#      x    y course
# 0  0.0  0.0      A
# 1  1.0  2.0      A
# 2  4.0  3.0      A
# 3  5.0  5.0      A
# 4  5.0  5.0      B
# 5  4.1  3.0      B
# 6  1.0  0.5      B
# 7  0.0  0.0      B

# %% [markdown]
# ### `7`. 빈칸에 적절한 값을 채워 심슨의 역설을 설명하는 예제를 완성하고 시각화 하라. (30점)

# %% [markdown]
# 다음은 농구선수 A,B의 시즌별 자유투 성공률이다.

# %% [markdown]
# | |시즌1|시즌2|
# |:-:|:-:|:-:|
# |A선수|7/10|?|
# |B선수|?|4/4|
# * 표안의 값은 성공횟수/총자유투시도

# %% [markdown]
# ?에 적절한 값을 채워 시즌 1,2 모두 B선수의 자유투 성공률이 높지만 시즌1-2를 전체 합치면 A선수의 자유투 성공률이 더 높도록 하라. (즉 ?에 적절한 값을 채워 심슨의 역설을 섦영하기 위한 자료를 구성하라.)
#
# 만들어진 자료를 바탕으로 심슨의 역설을 시각화하라. (즉 시즌 1,2의 자유투 성공률과 전체 자유트 성공률을 barplot으로 시각화하라)

# %% [markdown]
# | |시즌1|시즌2|
# |:-:|:-:|:-:|
# |A선수|7/10|81/90|
# |B선수|72/96|4/4|
#
# > 88/100 : 76/100

# %%
72/96
# Out:
# 0.75

# %%
season = np.concatenate([np.repeat('Season 1', 2), np.repeat('Season 2', 2)])
player = ['Player A', 'Player B', 'Player A', 'Player B']

# %%
success = [7, 72, 81, 4]
try_sum = [10, 96, 90, 4]

# %%
df = pd.DataFrame({'Season' : season, 'Player' : player, 'Success' : success, 'Try' : try_sum})
df
# Out:
#      Season    Player  Success  Try
# 0  Season 1  Player A        7   10
# 1  Season 1  Player B       72   96
# 2  Season 2  Player A       81   90
# 3  Season 2  Player B        4    4

# %%
df.assign(Success_Rate = df.Success/df['Try'])
# Out:
#      Season    Player  Success  Try  Success_Rate
# 0  Season 1  Player A        7   10          0.70
# 1  Season 1  Player B       72   96          0.75
# 2  Season 2  Player A       81   90          0.90
# 3  Season 2  Player B        4    4          1.00

# %%
df.assign(Success_Rate = df.Success/df['Try']).pivot_table(index = ['Player'], values = ['Success', 'Try'], aggfunc = 'sum').assign(Success_Rate = lambda _df : _df.Success / _df.Try)\
.reset_index().assign(Season = np.repeat('Total', 2))
# Out:
#      Player  Success  Try  Success_Rate Season
# 0  Player A       88  100          0.88  Total
# 1  Player B       76  100          0.76  Total

# %%
pd.concat([df.assign(Success_Rate = df.Success/df['Try']), df.assign(Success_Rate = df.Success/df['Try']).pivot_table(index = ['Player'], values = ['Success', 'Try'], aggfunc = 'sum').assign(Success_Rate = lambda _df : _df.Success / _df.Try)\
.reset_index().assign(Season = np.repeat('Total', 2))], axis = 0)\
.reset_index(drop = True)
# Out:
#      Season    Player  Success  Try  Success_Rate
# 0  Season 1  Player A        7   10          0.70
# 1  Season 1  Player B       72   96          0.75
# 2  Season 2  Player A       81   90          0.90
# 3  Season 2  Player B        4    4          1.00
# 4     Total  Player A       88  100          0.88
# 5     Total  Player B       76  100          0.76

# %%
tidydata = pd.concat([df.assign(Success_Rate = df.Success/df['Try']), df.assign(Success_Rate = df.Success/df['Try']).pivot_table(index = ['Player'], values = ['Success', 'Try'], aggfunc = 'sum').assign(Success_Rate = lambda _df : _df.Success / _df.Try)\
.reset_index().assign(Season = np.repeat('Total', 2))], axis = 0)\
.reset_index(drop = True)

fig = ggplot(tidydata)
bar = geom_col(aes(x = 'Player', y = 'Success_Rate', fill = 'Player'))

fig + bar + facet_wrap('Season')
# Out:
# <Figure Size: (640 x 480)>
