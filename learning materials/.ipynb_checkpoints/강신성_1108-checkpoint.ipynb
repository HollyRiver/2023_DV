# %% [markdown]
# Plotly with pandas-backend

# %% [markdown]
# \- pandas에서 plotly를 이용하여 플롯을 그려보자.

# %% [markdown]
# ## 1. 라이브러리 imports

# %%
import pandas as pd
import numpy as np
import plotly.io as pio

# %%
pd.options.plotting.backend = 'plotly'
pio.templates.default = 'plotly_white'
print(pio.templates)
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly_white'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %% [markdown]
# > 기본적으로 pandas의 backend는 matplotlib로 지정되어 있다. 이것을 plotly로 바꾸고 템플릿을 하얀색으로바꿨다.
#
# \- `backend = plotly`를 입력하지 않아도 되게 만들었음.

# %%
_df = pd.DataFrame({'x' : [1,2,3]})

# %%
_df.plot.line()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3253b2a8-f447-4700-83ad-b8b7a7aa66e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3253b2a8-f447-4700-83ad-b8b7a7aa66e7")) {                    Plotly.newPlot(                        "3253b2a8-f447-4700-83ad-b8b7a7aa66e7",                        [{"hovertemplate":"variable=x\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"x","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"x","orientation":"v","showlegend":true,"x":[0,1,2],"xaxis":"x","y":[1,2,3],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpo ...

# %% [markdown]
# > 알아서 `plotly`로 산출해주는 모습
#
# \- pie chart같은 것은 지원하지 않음.

# %% [markdown]
# ## 2. 여러가지 플랏
#
#
# ### **A. `.plot.bar()`**
# ---

# %% [markdown]
# \- 예제 1 : 성별 합격률 시각화

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guebin/DV2022/master/posts/Simpson.csv",index_col=0,header=[0,1]).reset_index().melt(id_vars='index').set_axis(['department','gender','result','count'],axis=1)
df  ## 파일에 index_column이 존재하고, 첫 행이 열이름인듯.
# Out:
#    department  gender result  count
# 0           A    male   fail    314
# 1           B    male   fail    208
# 2           C    male   fail    204
# 3           D    male   fail    279
# 4           E    male   fail    137
# 5           F    male   fail    149
# 6           A    male   pass    511
# 7           B    male   pass    352
# 8           C    male   pass    121
# 9           D    male   pass    138
# 10          E    male   pass     54
# 11          F    male   pass    224
# 12          A  female   fail     19
# 13          B  female   fail      7
# 14          C  female   fail    391
# 15          D  female   fail    244
# 16          E  female   fail    299
# 17          F  female   fail    103
# 18          A  female   pass     89
# 19          B  female   pass     18
# 20          C  female   pass    202
# 21          D  female   pass    131
# 22          E  female   pass     94
# 23          F  female   pass    238

# %%
df.pivot_table(index = 'gender', columns = 'result', values = 'count', aggfunc = 'sum')
# Out:
# result  fail  pass
# gender
# female  1063   772
# male    1291  1400

# %%
df.pivot_table(index = 'gender', columns = 'result', values = 'count', aggfunc = 'sum').assign(total = lambda _df : _df.fail + _df['pass'])\
.assign(rate = lambda _df : _df['pass']/_df.total)
# Out:
# result  fail  pass  total      rate
# gender
# female  1063   772   1835  0.420708
# male    1291  1400   2691  0.520253

# %%
df.pivot_table(index = 'gender', columns = 'result', values = 'count', aggfunc = 'sum').assign(total = lambda _df : _df.fail + _df['pass'])\
.assign(rate = lambda _df : _df['pass']/_df.total)\
.reset_index().drop(['fail', 'pass', 'total'], axis = 1)
# Out:
# result  gender      rate
# 0       female  0.420708
# 1         male  0.520253

# %% [markdown]
# \- 이상태에서 바로 시각화

# %%
df.pivot_table(index = 'gender', columns = 'result', values = 'count', aggfunc = 'sum').assign(total = lambda _df : _df.fail + _df['pass'])\
.assign(rate = lambda _df : _df['pass']/_df.total)\
.reset_index().drop(['fail', 'pass', 'total'], axis = 1)\
.assign(rate = lambda _df : _df.rate.apply(lambda x : round(x, 2)))\
.plot.bar(x = 'gender', y = 'rate', color = 'gender', text = 'rate', width = 600)    ## text 옵션으로 개체에 라벨링 가능, width나 height 옵션으로 크기 조절 가능
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="82feb554-7773-48cf-9af7-c90092af1e9b" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82feb554-7773-48cf-9af7-c90092af1e9b")) {                    Plotly.newPlot(                        "82feb554-7773-48cf-9af7-c90092af1e9b",                        [{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003erate=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"text":[0.42],"textposition":"auto","x":["female"],"xaxis":"x","y":[0.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003erate=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"v","showlegend":true,"text":[0.52],"textposition":"auto","x":["male"],"xaxis":"x","y":[0.52],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterp ...

# %% [markdown]
# \- 예제 2 : (성별, 학과) 별 지원자 수 시각화

# %%
df.pivot_table(index = ['department', 'gender'], values = 'count', aggfunc = 'sum')
# Out:
#                    count
# department gender
# A          female    108
#            male      825
# B          female     25
#            male      560
# C          female    593
#            male      325
# D          female    375
#            male      417
# E          female    393
#            male      191
# F          female    341
#            male      373

# %%
df.pivot_table(index = ['department', 'gender'], values = 'count', aggfunc = 'sum').reset_index()\
.plot.bar(x = 'gender', y = 'count', color = 'gender', facet_col = 'department', text = 'count', width = 800)  ## 면분할도 됨. facet_row는 지양할것
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="480e62af-34d2-4a9d-9e4b-ecc640b3f312" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("480e62af-34d2-4a9d-9e4b-ecc640b3f312")) {                    Plotly.newPlot(                        "480e62af-34d2-4a9d-9e4b-ecc640b3f312",                        [{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=A\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":true,"text":[108.0],"textposition":"auto","x":["female"],"xaxis":"x","y":[108],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=B\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":false,"text":[25.0],"textposition":"auto","x":["female"],"xaxis":"x2","y":[25],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=C\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":false,"text":[593.0],"textposition":"auto","x":["female"],"xaxis":"x3","y":[593],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=D\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":false,"text":[375.0],"textposition":"auto","x":["female"],"xaxis":"x4","y":[375],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=E\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":false,"text":[393.0],"textposition":"auto","x":["female"],"xaxis":"x5","y":[393],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=F\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"female","offsetgroup":"female","orientation":"v","showlegend":false,"text":[341.0],"textposition":"auto","x":["female"],"xaxis":"x6","y":[341],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=A\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"v","showlegend":true,"text":[825.0],"textposition":"auto","x":["male"],"xaxis":"x","y":[825],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=B\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"v","showlegend":false,"text":[560.0],"textposition":"auto","x":["male"],"xaxis":"x2","y":[560],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003edepartment=C\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"male","offsetgroup":"m ...

# %% [markdown]
# ### **B. `plot.line()`**
# ---

# %% [markdown]
# \- 예제 1 : 핸드폰 판매량

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/phone.csv')
df
# Out:
#        Date  Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola  LG  \
# 0   2019-10      461    324     136     109    76       81        43  37
# 1   2019-11      461    358     167     141    86       61        29  36
# 2   2019-12      426    383     143     105    53       45        51  48
# 3   2020-01      677    494     212     187   110       79        65  49
# 4   2020-02      593    520     217     195   112       67        62  71
# 5   2020-03      637    537     246     187    92       66        59  67
# 6   2020-04      647    583     222     154    98       59        48  64
# 7   2020-05      629    518     192     176    91       87        50  66
# 8   2020-06      663    552     209     185    93       69        54  60
# 9   2020-07      599    471     214     193    89       78        65  59
# 10  2020-08      615    567     204     182   105       82        62  42
# 11  2020-09      621    481     230     220   102       88        56  49
# 12  2020-10      637    555     232     203    90       52        63  49
#
#     Others  Realme  Google  Nokia  Lenovo  OnePlus  Sony  Asus
# 0      135      28      39     14      22       17    20    17
# 1      141      27      29     20      23       10    19    27
# 2      129      30      20     26      28       18    18    19
# 3      158      23      13     19      19       22    27    22
# 4      157      25      18     16      24       18    23    20
# 5      145      21      16     24      18       31    22    14
# 6      113      20      23     25      19       19    23    21
# 7      150      43      27     15      18       19    19    13
# 8      140      39      16     16      17       29    25    16
# 9      130      40      27     25      21       18    18    12
# 10     129      47      16     23      21       27    23    20
# 11     143      54      14     15      17       15    19    15
# 12     140      33      17     20      22        9    22    21

# %%
df.melt(id_vars = 'Date').set_axis(['날짜','회사','판매량'], axis = 1)
# Out:
#           날짜       회사  판매량
# 0    2019-10  Samsung  461
# 1    2019-11  Samsung  461
# 2    2019-12  Samsung  426
# 3    2020-01  Samsung  677
# 4    2020-02  Samsung  593
# ..       ...      ...  ...
# 203  2020-06     Asus   16
# 204  2020-07     Asus   12
# 205  2020-08     Asus   20
# 206  2020-09     Asus   15
# 207  2020-10     Asus   21
#
# [208 rows x 3 columns]

# %%
df.melt(id_vars = 'Date').set_axis(['날짜','회사','판매량'], axis = 1)\
.plot.line(x = '날짜', y = '판매량', color = '회사', width = 800)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="58887efe-4de2-4d26-90f2-d4649a23b970" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58887efe-4de2-4d26-90f2-d4649a23b970")) {                    Plotly.newPlot(                        "58887efe-4de2-4d26-90f2-d4649a23b970",                        [{"hovertemplate":"\ud68c\uc0ac=Samsung\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Samsung","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Samsung","orientation":"v","showlegend":true,"x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[461,461,426,677,593,637,647,629,663,599,615,621,637],"yaxis":"y","type":"scatter"},{"hovertemplate":"\ud68c\uc0ac=Apple\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Apple","orientation":"v","showlegend":true,"x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[324,358,383,494,520,537,583,518,552,471,567,481,555],"yaxis":"y","type":"scatter"},{"hovertemplate":"\ud68c\uc0ac=Huawei\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Huawei","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Huawei","orientation":"v","showlegend":true,"x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[136,167,143,212,217,246,222,192,209,214,204,230,232],"yaxis":"y","type":"scatter"},{"hovertemplate":"\ud68c\uc0ac=Xiaomi\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Xiaomi","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Xiaomi","orientation":"v","showlegend":true,"x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[109,141,105,187,195,187,154,176,185,193,182,220,203],"yaxis":"y","type":"scatter"},{"hovertemplate":"\ud68c\uc0ac=Oppo\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oppo","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Oppo","orientation":"v","showlegend":true,"x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[76,86,53,110,112,92,98,91,93,89,105,102,90],"yaxis":"y","type":"scatter"},{"hovertemplate":"\ud68c\uc0ac=Mobicel\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mobicel","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mobicel","orientation":"v","showlegend":true,"x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[81,61,45,79,67,66,59,87,69,78,82,88,52],"yaxis":"y","type":"scatter"},{"hovertemplate":"\ud68c\uc0ac=Motorola\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Motorola","line":{"color":"#FF66 ...

# %% [markdown]
# ### **C. `.plot.scatter()`**
# ---

# %% [markdown]
# \- 예제 1 : FIFA23 data

# %%
position_dict = {
    'GOALKEEPER':{'GK'},
    'DEFENDER':{'CB','RCB','LCB','RB','LB','RWB','LWB'},
    'MIDFIELDER':{'CM','RCM','LCM','CDM','RDM','LDM','CAM','RAM','LAM','RM','LM'},
    'FORWARD':{'ST','CF','RF','LF','RW','LW','RS','LS'},
    'SUB':{'SUB'},
    'RES':{'RES'}
}
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2021/master/_notebooks/2021-10-25-FIFA22_official_data.csv')\
.loc[:,lambda df: df.isna().mean()<0.5].dropna()\
.assign(Position = lambda df: df.Position.str.split(">").str[-1].apply(lambda x: [k for k,v in position_dict.items() if x in v].pop()))\
.assign(Wage = lambda df: df.Wage.str[1:].str.replace('K','000').astype(int))
df
# Out:
#            ID             Name  Age  \
# 0      212198  Bruno Fernandes   26
# 1      209658      L. Goretzka   26
# 2      176580        L. Suárez   34
# 3      192985     K. De Bruyne   30
# 4      224334         M. Acuña   29
# ...       ...              ...  ...
# 16703  259718      F. Gebhardt   19
# 16704  251433          B. Voll   20
# 16706  262846         �. Dobre   20
# 16707  241317   21 Xue Qinghao   19
# 16708  259646        A. Shaikh   18
#
#                                                   Photo Nationality  \
# 0      https://cdn.sofifa.com/players/212/198/22_60.png    Portugal
# 1      https://cdn.sofifa.com/players/209/658/22_60.png     Germany
# 2      https://cdn.sofifa.com/players/176/580/22_60.png     Uruguay
# 3      https://cdn.sofifa.com/players/192/985/22_60.png     Belgium
# 4      https://cdn.sofifa.com/players/224/334/22_60.png   Argentina
# ...                                                 ...         ...
# 16703  https://cdn.sofifa.com/players/259/718/22_60.png     Germany
# 16704  https://cdn.sofifa.com/players/251/433/22_60.png     Germany
# 16706  https://cdn.sofifa.com/players/262/846/22_60.png     Romania
# 16707  https://cdn.sofifa.com/players/241/317/21_60.png    China PR
# 16708  https://cdn.sofifa.com/players/259/646/22_60.png       India
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.com/flags/pt.png       88         89
# 1      https://cdn.sofifa.com/flags/de.png       87         88
# 2      https://cdn.sofifa.com/flags/uy.png       88         88
# 3      https://cdn.sofifa.com/flags/be.png       91         91
# 4      https://cdn.sofifa.com/flags/ar.png       84         84
# ...                                    ...      ...        ...
# 16703  https://cdn.sofifa.com/flags/de.png       52         66
# 16704  https://cdn.sofifa.com/flags/de.png       58         69
# 16706  https://cdn.sofifa.com/flags/ro.png       53         63
# 16707  https://cdn.sofifa.com/flags/cn.png       47         60
# 16708  https://cdn.sofifa.com/flags/in.png       47         67
#
#                         Club                                   Club Logo  ...  \
# 0          Manchester United      https://cdn.sofifa.com/teams/11/30.png  ...
# 1          FC Bayern München      https://cdn.sofifa.com/teams/21/30.png  ...
# 2         Atlético de Madrid     https://cdn.sofifa.com/teams/240/30.png  ...
# 3            Manchester City      https://cdn.sofifa.com/teams/10/30.png  ...
# 4                 Sevilla FC     https://cdn.sofifa.com/teams/481/30.png  ...
# ...                      ...                                         ...  ...
# 16703          FC Basel 1893     https://cdn.sofifa.com/teams/896/30.png  ...
# 16704     F.C. Hansa Rostock      https://cdn.sofifa.com/teams/27/30.png  ...
# 16706  FC Academica Clinceni  https://cdn.sofifa.com/teams/113391/30.png  ...
# 16707    Shanghai Shenhua FC  https://cdn.sofifa.com/teams/110955/30.png  ...
# 16708     ATK Mohun Bagan FC  https://cdn.sofifa.com/teams/113146/30.png  ...
#
#       SlidingTackle  GKDiving  GKHandling GKKicking  GKPositioning  \
# 0              65.0      12.0        14.0      15.0            8.0
# 1              77.0      13.0         8.0      15.0           11.0
# 2              38.0      27.0        25.0      31.0           33.0
# 3              53.0      15.0        13.0       5.0           10.0
# 4              82.0       8.0        14.0      13.0           13.0
# ...             ...       ...         ...       ...            ...
# 16703          10.0      53.0        45.0      47.0           52.0
# 16704          10.0      59.0        60.0      56.0           55.0
# 16706          12.0      57.0        52.0      53.0           48.0
# 16707           9.0      49.0        48.0      45.0           38.0
# 16708          13.0      49.0        41.0      39.0           45.0
#
#        GKReflexes  Best Position Best Overall Rating Release Clause  \
# 0            14.0            CAM                88.0        €206.9M
# 1             9.0             CM                87.0        €160.4M
# 2            37.0             ST                88.0         €91.2M
# 3            13.0             CM                91.0        €232.2M
# 4            14.0             LB                84.0         €77.7M
# ...           ...            ...                 ...            ...
# 16703        57.0             GK                52.0          €361K
# 16704        61.0             GK                58.0          €656K
# 16706        58.0             GK                53.0          €279K
# 16707        52.0             GK                47.0          €223K
# 16708        49.0             GK                47.0          €259K
#
#       DefensiveAwareness
# 0                   72.0
# 1                   74.0
# 2                   42.0
# 3                   68.0
# 4                   80.0
# ...                  ...
# 16703                6.0
# 16704                5.0
# 16706                5.0
# 16707               21.0
# 16708                7.0
#
# [14398 rows x 63 columns]

# %%
df.query('Position == "DEFENDER" or Position == "FORWARD"')\
.plot.scatter(x = 'ShotPower', y = 'StandingTackle',
              color = 'Position', size = 'Wage', hover_data = ['Name', 'Age'],
              opacity = 0.5, width = 800)    ## alpha가 아니라 opacity(불투명)로 설정함, hover_data로 마우스를 갖다댔을 때 추가적인 정보를 넣어줄 수 있음.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="003e3c4b-6bfb-470d-8985-6000faba9810" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("003e3c4b-6bfb-470d-8985-6000faba9810")) {                    Plotly.newPlot(                        "003e3c4b-6bfb-470d-8985-6000faba9810",                        [{"customdata":[["L. Su\u00e1rez",34],["L. Messi",34],["L. Ocampos",26],["R. Lewandowski",32],["M. Salah",29],["Cristiano Ronaldo",36],["H. Kane",27],["R. Malinovskyi",28],["S. Man\u00e9",29],["Neymar Jr",29],["Roberto Firmino",29],["K. Mbapp\u00e9",22],["Ra\u00fal Garc\u00eda",34],["L. Mart\u00ednez",23],["H. Son",28],["A. Golovin",25],["J. Vardy",34],["21\u00a0Hulk",33],["K. Volland",28],["Morales",33],["Gerard Moreno",29],["K. Benzema",33],["G. Moreno",35],["M. Antonio",31],["M. Arnautovi\u0107",32],["D. Tadi\u0107",32],["W. Ben Yedder",30],["E. Haaland",20],["M. Mount",22],["Pedro Gon\u00e7alves",23],["R. Jim\u00e9nez",30],["Lucas Moura",28],["M. Su\u00e1rez",33],["M. Depay",27],["21\u00a0A. Ayew",30],["L. Rodr\u00edguez",36],["Iago Aspas",33],["S. Ag\u00fcero",33],["N. Lodeiro",32],["C. Immobile",31],["R. Lukaku",28],["Andr\u00e9 Silva",25],["S. Serdar",24],["Oyarzabal",24],["S. Zuber",29],["A. Delort",29],["D. Ings",28],["S. Amallah",24],["F. Acheampong",27],["E. Zahavi",33],["A. Plea",28],["P. Aubameyang",32],["N. Amrabat",34],["I\u00f1aki Williams",27],["K. Havertz",22],["R. Mahrez",30],["J. Ito",28],["G. Laborde",27],["Jo\u00e3o Pedro",29],["A. Bar\u00e1k",26],["J. Fuenzalida",36],["L.
    'Class' : ['A']*len(y1) + ['B']*len(y2),
    'Score' : y1+y2
})
df
# Out:
#    Class  Score
# 0      A     75
# 1      A     75
# 2      A     76
# 3      A     76
# 4      A     77
# 5      A     77
# 6      A     78
# 7      A     79
# 8      A     79
# 9      A     98
# 10     B     76
# 11     B     76
# 12     B     77
# 13     B     77
# 14     B     78
# 15     B     78
# 16     B     79
# 17     B     80
# 18     B     80
# 19     B     81

# %%
df.plot.box(x = 'Class', y = 'Score', color = 'Class',
            points = 'all', width = 500)   ## points 옵션을 사용해서 점도 직접 띄워줄 수 있음
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="715e0ddf-0970-4e88-a004-0c57881f7bb5" class="plotly-graph-div" style="height:525px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("715e0ddf-0970-4e88-a004-0c57881f7bb5")) {                    Plotly.newPlot(                        "715e0ddf-0970-4e88-a004-0c57881f7bb5",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Class=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","marker":{"color":"#636efa"},"name":"A","notched":false,"offsetgroup":"A","orientation":"v","showlegend":true,"x":["A","A","A","A","A","A","A","A","A","A"],"x0":" ","xaxis":"x","y":[75,75,76,76,77,77,78,79,79,98],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Class=%{x}\u003cbr\u003eScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B"},"name":"B","notched":false,"offsetgroup":"B","orientation":"v","showlegend":true,"x":["B","B","B","B","B","B","B","B","B","B"],"x0":" ","xaxis":"x","y":[76,76,77,77,78,78,79,80,80,81],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"pa ...

# %% [markdown]
# \- 예제 2 : (년도, 시도)별 전기에너지 사용량

# %%
url = 'https://raw.githubusercontent.com/guebin/DV2022/main/posts/Energy/{}.csv'
prov = ['Seoul', 'Busan', 'Daegu', 'Incheon',
        'Gwangju', 'Daejeon', 'Ulsan', 'Sejongsi',
        'Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do',
        'Chungcheongnam-do', 'Jeollabuk-do', 'Jeollanam-do',
        'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Jeju-do']
df = pd.concat([pd.read_csv(url.format(p+y)).assign(년도=y, 시도=p) for p in prov for y in ['2018', '2019', '2020', '2021']]).reset_index(drop=True)\
.assign(년도 = lambda df: df.년도.astype(int))\
.set_index(['년도','시도','지역']).applymap(lambda x: int(str(x).replace(',','')))\
.reset_index()
df.head()
# Out:
#      년도     시도   지역   건물동수       연면적  에너지사용량(TOE)/전기  에너지사용량(TOE)/도시가스  \
# 0  2018  Seoul  종로구  17929   9141777           64818             82015
# 1  2018  Seoul   중구  10598  10056233           81672             75260
# 2  2018  Seoul  용산구  17201  10639652           52659             85220
# 3  2018  Seoul  성동구  14180  11631770           60559            107416
# 4  2018  Seoul  광진구  21520  12054796           70609            130308
#
#    에너지사용량(TOE)/지역난방
# 0               111
# 1               563
# 2             12043
# 3                 0
# 4                 0

# %%
## 그냥 바로 해도 됨(이미 타이디데이터임)
df.plot.box(x = '시도', y = '에너지사용량(TOE)/전기', color = '시도', facet_row = '년도', height = 1600, width = 800, hover_data = ['지역','연면적'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="57537ac2-a67d-40f7-a07b-cf054bb2bb8e" class="plotly-graph-div" style="height:1600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9(TOE)\u002f\uc804\uae30=%{y}\u003cbr\u003e\uc9c0\uc5ed=%{customdata[0]}\u003cbr\u003e\uc5f0\uba74\uc801=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Seoul","marker":{"color":"#636efa"},"name":"Seoul","notched":false,"offsetgroup":"Seoul","orientation":"v","showlegend":false,"x":["Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul","Seoul"],"x0":" ","xaxis":"x3","y":[63492,79223,51229,59832,68756,65913,59370,77007,47731,44985,77010,75914,65164,92453,70721,86809,59916,34791,87480,66811,85416,135491,180121,139117,70341],"y0":" ","yaxis":"y3","type":"box"},{"alignmentgroup":"True","customdata":[["\uc885\ub85c\u ...

# %% [markdown]
# ### **E. `.plot.hist()`**
# ---

# %% [markdown]
# \- 예제 1 : 타이타닉 (연령, 성별) 생존자

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guebin/DV2023/main/posts/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked   logFare
# 0        0         A/5 21171   7.2500   NaN        S  1.981001
# 1        0          PC 17599  71.2833   C85        C  4.266662
# 2        0  STON/O2. 3101282   7.9250   NaN        S  2.070022
# 3        0            113803  53.1000  C123        S  3.972177
# 4        0            373450   8.0500   NaN        S  2.085672
# ..     ...               ...      ...   ...      ...       ...
# 886      0            211536  13.0000   NaN        S  2.564949
# 887      0            112053  30.0000   B42        S  3.401197
# 888      2        W./C. 6607  23.4500   NaN        S  3.154870
# 889      0            111369  30.0000  C148        C  3.401197
# 890      0            370376   7.7500   NaN        Q  2.047693
#
# [891 rows x 13 columns]

# %%
df.Age.hist()  ## 바로 히스토그램 그릴 수도 있음(시리즈에서)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4e82a40e-f805-4772-bd4c-ad6ddbd357f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e82a40e-f805-4772-bd4c-ad6ddbd357f9")) {                    Plotly.newPlot(                        "4e82a40e-f805-4772-bd4c-ad6ddbd357f9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=Age\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Age","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Age","offsetgroup":"Age","orientation":"v","showlegend":true,"x":[22.0,38.0,26.0,35.0,35.0,null,54.0,2.0,27.0,14.0,4.0,58.0,20.0,39.0,14.0,55.0,2.0,null,31.0,null,35.0,34.0,15.0,28.0,8.0,38.0,null,19.0,null,null,40.0,null,null,66.0,28.0,42.0,null,21.0,18.0,14.0,40.0,27.0,null,3.0,19.0,null,null,null,null,18.0,7.0,21.0,49.0,29.0,65.0,null,21.0,28.5,5.0,11.0,22.0,38.0,45.0,4.0,null,null,29.0,19.0,17.0,26.0,32.0,16.0,21.0,26.0,32.0,25.0,null,null,0.83,30.0,22.0,29.0,null,28.0,17.0,33.0,16.0,null,23.0,24.0,29.0,20.0,46.0,26.0,59.0,null,71.0,23.0,34.0,34.0,28.0,null,21.0,33.0,37.0,28.0,21.0,null,38.0,null,47.0,14.5,22.0,20.0,17.0,21.0,70.5,29.0,24.0,2.0,21.0,null,32.5,32.5,54.0,12.0,null,24.0,null,45.0,33.0,20.0,47.0,29.0,25.0,23.0,19.0,37.0,16.0,24.0,null,22.0,24.0,19.0,18.0,19.0,27.0,9.0,36.5,42.0,51.0,22.0,55.5,40.5,null,51.0,16.0,30.0,null,null,44.
,34.0,26.0,27.0,21.0,21.0,61.0,57.0,26.0,null,51.0,null,32.0,31.0,null,20.0,19.0,null,null,21.0,24.0,null,23.0,58.0,40.0,47.0,36.0,32.0,25.0,null,43.0,31.0,70.0,null,18.0,24.5,20.0,14.0,60.0,25.0,14.0,19.0,18.0,25.0,60.0,52.0,44.0,49.0,42.0,25.0,26.0,39.0,null,29.0,52.0,19.0,null,33.0,17.0,34.0,50.0,20.0,25.0,11.0,null,23.0,23.0,28.5,null,null,36.0,24.0,70.0,16.0,19.0,31.0,33.0,23.0,28.0,18.0,34.0,null,41.0,16.0,null,null,32.0,24.0,48.0,null,18.0,null,null,29.0,null,25.0,25.0,8.0,46.0,null,16.0,null,25.0,39.0,30.0,34.0,31.0,39.0,39.0,26.0,39.0,35.0,30.5,null,31.0,43.0,10.0,38.0,2.0,null,null,null,23.0,18.0,21.0,null,20.0,16.0,34.5,17.0,42.0,null,35.0,28.0,4.0,74.0,null,41.0,21.0,24.0,31.0,null,26.0,33.0,47.0,20.0,19.0,null,33.0,28.0,25.0,27.0,32.0],"xaxis":"x3","yaxis":"y3","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Sex=male\u003cbr\u003eSurvived=1\u003cbr\u003eAge=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"male","offsetgroup":"male","orientation":"v","showlegend":false,"x":[null,34.0,28.0,null,null,null,32.0,0.83,29.0,23.0,null,12.0,24.0,27.0,9.0,1.0,45.0,3.0,18.0,26.0,40.0,16.0,38.0,19.0,37.0,3.0,25.0,25.0,19.0,30.0,42.0,null,null,0.92,45.0,2.0,3.0,25.0,36.0,21.0,39.0,3.0,44.0,32.0,28.0,null,4.0,34.0,52.0,49.0,29.0,48.0,25.0,9.0,null,26.0,29.0,36.0,32.0,null,8.0,17.0,22.0,32.0,62.0,36.0,32.0,60.0,49.0,35.0,27.0,42.0,20.0,80.0,32.0,null,48.0,56.0,50.0,20.0,31.0,36.0,27.0,31.0 ...

# %% [markdown]
# > 성별 효과가 15세 이상에서는 있었고, 그 아래에서는 없는 것 같다.

# %% [markdown]
# ### **F. `.plot.area()`**
# ---

# %% [markdown]
# \- 예제 1 : 핸드폰 판매량

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/2021DV/master/_notebooks/phone.csv')
df
# Out:
#        Date  Samsung  Apple  Huawei  Xiaomi  Oppo  Mobicel  Motorola  LG  \
# 0   2019-10      461    324     136     109    76       81        43  37
# 1   2019-11      461    358     167     141    86       61        29  36
# 2   2019-12      426    383     143     105    53       45        51  48
# 3   2020-01      677    494     212     187   110       79        65  49
# 4   2020-02      593    520     217     195   112       67        62  71
# 5   2020-03      637    537     246     187    92       66        59  67
# 6   2020-04      647    583     222     154    98       59        48  64
# 7   2020-05      629    518     192     176    91       87        50  66
# 8   2020-06      663    552     209     185    93       69        54  60
# 9   2020-07      599    471     214     193    89       78        65  59
# 10  2020-08      615    567     204     182   105       82        62  42
# 11  2020-09      621    481     230     220   102       88        56  49
# 12  2020-10      637    555     232     203    90       52        63  49
#
#     Others  Realme  Google  Nokia  Lenovo  OnePlus  Sony  Asus
# 0      135      28      39     14      22       17    20    17
# 1      141      27      29     20      23       10    19    27
# 2      129      30      20     26      28       18    18    19
# 3      158      23      13     19      19       22    27    22
# 4      157      25      18     16      24       18    23    20
# 5      145      21      16     24      18       31    22    14
# 6      113      20      23     25      19       19    23    21
# 7      150      43      27     15      18       19    19    13
# 8      140      39      16     16      17       29    25    16
# 9      130      40      27     25      21       18    18    12
# 10     129      47      16     23      21       27    23    20
# 11     143      54      14     15      17       15    19    15
# 12     140      33      17     20      22        9    22    21

# %%
df.melt(id_vars = 'Date').set_axis(['날짜', '회사', '판매량'], axis = 1)\
.plot.area(x = '날짜', y = '판매량', color = '회사')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52c30b4c-d42c-4bf1-b805-001a5ae287e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52c30b4c-d42c-4bf1-b805-001a5ae287e6")) {                    Plotly.newPlot(                        "52c30b4c-d42c-4bf1-b805-001a5ae287e6",                        [{"fillpattern":{"shape":""},"hovertemplate":"\ud68c\uc0ac=Samsung\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Samsung","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Samsung","orientation":"v","showlegend":true,"stackgroup":"1","x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[461,461,426,677,593,637,647,629,663,599,615,621,637],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\ud68c\uc0ac=Apple\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Apple","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Apple","orientation":"v","showlegend":true,"stackgroup":"1","x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[324,358,383,494,520,537,583,518,552,471,567,481,555],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\ud68c\uc0ac=Huawei\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Huawei","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"Huawei","orientation":"v","showlegend":true,"stackgroup":"1","x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[136,167,143,212,217,246,222,192,209,214,204,230,232],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\ud68c\uc0ac=Xiaomi\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Xiaomi","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Xiaomi","orientation":"v","showlegend":true,"stackgroup":"1","x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[109,141,105,187,195,187,154,176,185,193,182,220,203],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\ud68c\uc0ac=Oppo\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oppo","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"Oppo","orientation":"v","showlegend":true,"stackgroup":"1","x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[76,86,53,110,112,92,98,91,93,89,105,102,90],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\ud68c\uc0ac=Mobicel\u003cbr\u003e\ub0a0\uc9dc=%{x}\u003cbr\u003e\ud310\ub9e4\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mobicel","line":{"color":"#19d3f3"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mobicel","orientation":"v","showlegend":true,"stackgroup":"1","x":["2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10"],"xaxis":"x","y":[81,61,45,79,67,66,59,87,69,78,82,88,52],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape" ...

# %% [markdown]
# > 전체적인 판매량과 비중을 알 수 있음과 동시에 경향성을 알 수 있음

# %% [markdown]
# \- 예제 2 : 에너지 사용량

# %%
url = 'https://raw.githubusercontent.com/guebin/DV2022/main/posts/Energy/{}.csv'
prov = ['Seoul', 'Busan', 'Daegu', 'Incheon',
        'Gwangju', 'Daejeon', 'Ulsan', 'Sejongsi',
        'Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do',
        'Chungcheongnam-do', 'Jeollabuk-do', 'Jeollanam-do',
        'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Jeju-do']
df = pd.concat([pd.read_csv(url.format(p+y)).assign(년도=y, 시도=p) for p in prov for y in ['2018', '2019', '2020', '2021']]).reset_index(drop=True)\
.assign(년도 = lambda df: df.년도.astype(int))\
.set_index(['년도','시도','지역']).applymap(lambda x: int(str(x).replace(',','')))\
.reset_index()
df.head()
# Out:
#      년도     시도   지역   건물동수       연면적  에너지사용량(TOE)/전기  에너지사용량(TOE)/도시가스  \
# 0  2018  Seoul  종로구  17929   9141777           64818             82015
# 1  2018  Seoul   중구  10598  10056233           81672             75260
# 2  2018  Seoul  용산구  17201  10639652           52659             85220
# 3  2018  Seoul  성동구  14180  11631770           60559            107416
# 4  2018  Seoul  광진구  21520  12054796           70609            130308
#
#    에너지사용량(TOE)/지역난방
# 0               111
# 1               563
# 2             12043
# 3                 0
# 4                 0

# %%
df.set_index(['년도','시도','지역','건물동수','연면적']).stack().reset_index().rename({'level_5' : '에너지종류', 0 : '에너지사용량'}, axis = 1)\
.assign(에너지종류 = lambda _df : _df.에너지종류.str.split('/').str[-1])
# Out:
#         년도       시도    지역   건물동수       연면적 에너지종류  에너지사용량
# 0     2018    Seoul   종로구  17929   9141777    전기   64818
# 1     2018    Seoul   종로구  17929   9141777  도시가스   82015
# 2     2018    Seoul   종로구  17929   9141777  지역난방     111
# 3     2018    Seoul    중구  10598  10056233    전기   81672
# 4     2018    Seoul    중구  10598  10056233  도시가스   75260
# ...    ...      ...   ...    ...       ...   ...     ...
# 2995  2021  Jeju-do   제주시  67053  20275738  도시가스   25689
# 2996  2021  Jeju-do   제주시  67053  20275738  지역난방       0
# 2997  2021  Jeju-do  서귀포시  35230   7512206    전기   37884
# 2998  2021  Jeju-do  서귀포시  35230   7512206  도시가스    2641
# 2999  2021  Jeju-do  서귀포시  35230   7512206  지역난방       0
#
# [3000 rows x 7 columns]

# %%
df.set_index(['년도','시도','지역','건물동수','연면적']).stack().reset_index().rename({'level_5' : '에너지종류', 0 : '에너지사용량'}, axis = 1)\
.assign(에너지종류 = lambda _df : _df.에너지종류.str.split('/').str[-1])\
.pivot_table(index = ['에너지종류', '시도', '년도'], values = '에너지사용량', aggfunc = 'sum').reset_index()
# Out:
#     에너지종류                 시도    년도  에너지사용량
# 0    도시가스              Busan  2018  708240
# 1    도시가스              Busan  2019  675882
# 2    도시가스              Busan  2020  690015
# 3    도시가스              Busan  2021  878874
# 4    도시가스  Chungcheongbuk-do  2018  288927
# ..    ...                ...   ...     ...
# 199  지역난방              Seoul  2021  546491
# 200  지역난방              Ulsan  2018       0
# 201  지역난방              Ulsan  2019       0
# 202  지역난방              Ulsan  2020       0
# 203  지역난방              Ulsan  2021       0
#
# [204 rows x 4 columns]

# %%
df.set_index(['년도','시도','지역','건물동수','연면적']).stack().reset_index().rename({'level_5' : '에너지종류', 0 : '에너지사용량'}, axis = 1)\
.assign(에너지종류 = lambda _df : _df.에너지종류.str.split('/').str[-1])\
.pivot_table(index = ['에너지종류', '시도', '년도'], values = '에너지사용량', aggfunc = 'sum').reset_index()\
.plot.area(x = '년도', y = '에너지사용량', facet_col = '에너지종류', color = '시도', width = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8b08e841-a871-4794-891b-8d57ed8a4354" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b08e841-a871-4794-891b-8d57ed8a4354")) {                    Plotly.newPlot(                        "8b08e841-a871-4794-891b-8d57ed8a4354",                        [{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Busan\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\ub3c4\uc2dc\uac00\uc2a4\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Busan","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Busan","orientation":"v","showlegend":true,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x","y":[708240,675882,690015,878874],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Busan\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc804\uae30\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Busan","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Busan","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x2","y":[613522,602980,601071,1043425],"yaxis":"y2","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Busan\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc9c0\uc5ed\ub09c\ubc29\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Busan","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Busan","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x3","y":[23694,22560,23014,29610],"yaxis":"y3","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongbuk-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\ub3c4\uc2dc\uac00\uc2a4\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chungcheongbuk-do","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chungcheongbuk-do","orientation":"v","showlegend":true,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x","y":[288927,291981,294442,308636],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongbuk-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc804\uae30\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chungcheongbuk-do","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chungcheongbuk-do","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x2","y":[361490,351235,347927,352396],"yaxis":"y2","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongbuk-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc9c0\uc5ed\ub09c\ubc29\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chungcheongbuk-do","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chungcheongbuk-do","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x3","y":[55002,52319,52738,56969],"yaxis":"y3","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongnam-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\ub3c4\uc2dc\uac00\uc2a4\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\ ...

# %% [markdown]
# > 연도가 겹치는 문제 해결을 위한 미세조정

# %%
## figure로 저장
fig = df.set_index(['년도','시도','지역','건물동수','연면적']).stack().reset_index().rename({'level_5' : '에너지종류', 0 : '에너지사용량'}, axis = 1)\
.assign(에너지종류 = lambda _df : _df.에너지종류.str.split('/').str[-1])\
.pivot_table(index = ['에너지종류', '시도', '년도'], values = '에너지사용량', aggfunc = 'sum').reset_index()\
.plot.area(x = '년도', y = '에너지사용량', facet_col = '에너지종류', color = '시도', width = 600)

## 아마도 xaxis3에서 년도가 들어갈 수 있는 영역을 한정해주는듯
fig.update_layout(
    xaxis_domain = [0.0, 0.25],
    xaxis2_domain = [0.35, 0.60],
    xaxis3_domain = [0.70, 0.95]
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="abb4d424-2677-4d30-917c-8377899f7864" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abb4d424-2677-4d30-917c-8377899f7864")) {                    Plotly.newPlot(                        "abb4d424-2677-4d30-917c-8377899f7864",                        [{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Busan\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\ub3c4\uc2dc\uac00\uc2a4\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Busan","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Busan","orientation":"v","showlegend":true,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x","y":[708240,675882,690015,878874],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Busan\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc804\uae30\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Busan","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Busan","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x2","y":[613522,602980,601071,1043425],"yaxis":"y2","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Busan\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc9c0\uc5ed\ub09c\ubc29\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Busan","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Busan","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x3","y":[23694,22560,23014,29610],"yaxis":"y3","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongbuk-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\ub3c4\uc2dc\uac00\uc2a4\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chungcheongbuk-do","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chungcheongbuk-do","orientation":"v","showlegend":true,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x","y":[288927,291981,294442,308636],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongbuk-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc804\uae30\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chungcheongbuk-do","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chungcheongbuk-do","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x2","y":[361490,351235,347927,352396],"yaxis":"y2","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongbuk-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\uc9c0\uc5ed\ub09c\ubc29\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\uc0ac\uc6a9\ub7c9=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chungcheongbuk-do","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chungcheongbuk-do","orientation":"v","showlegend":false,"stackgroup":"1","x":[2018,2019,2020,2021],"xaxis":"x3","y":[55002,52319,52738,56969],"yaxis":"y3","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\uc2dc\ub3c4=Chungcheongnam-do\u003cbr\u003e\uc5d0\ub108\uc9c0\uc885\ub958=\ub3c4\uc2dc\uac00\uc2a4\u003cbr\u003e\ub144\ub3c4=%{x}\u003cbr\u003e\uc5d0\ub108\uc9c0\ ...
