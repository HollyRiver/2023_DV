# %% [markdown]
# 심슨의 역설

# %% [markdown]
# > ...

# %% [markdown]
# ## 1. 라이브러리 imports

# %%
import pandas as pd
import numpy as np
from plotnine import *

# %% [markdown]
# ## 2. 비교를 위한 시각화

# %% [markdown]
# ### **A. `geom_col`()**
# ---
# \- 예시1 : 기본적인 막대 그래프

# %%
df = pd.DataFrame({'x':[0,1],'y':[40,60]})
df
# Out:
#    x   y
# 0  0  40
# 1  1  60

# %%
fig = ggplot(df)
bar = geom_col(aes(x = 'x', y = 'y'))   ## geom_bar()는 그냥 없다고 생각하자.

fig + bar
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# \- 예시2 : $x$축이 범주형인 경우

# %%
df = pd.DataFrame({'sex':['male','female'],'score':[40,60]})
df
# Out:
#       sex  score
# 0    male     40
# 1  female     60

# %%
fig = ggplot(df)
bar = geom_col(aes(x = 'sex', y = 'score'))   ## 설명변수가 문자열이어도 산출해준다.

fig + bar
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# \- 예시3 : 예시2에서 범주별 색깔로 구분하고 싶은 경우

# %%
df = pd.DataFrame({'sex':['male','female'],'score':[40,60]})
df
# Out:
#       sex  score
# 0    male     40
# 1  female     60

# %%
fig = ggplot(df)
bar = geom_col(aes(x = 'sex', y = 'score', fill = 'sex'))   ## color 옵션도 있으나, 이것은 바깥의 테두리 색상만 바꾼다.

fig + bar
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# \- 예시4 : 예시3에서 `scale_fill_manual()`을 이용하여 색상 변경하기

# %%
df = pd.DataFrame({'sex':['male','female'],'score':[40,60]})
df
# Out:
#       sex  score
# 0    male     40
# 1  female     60

# %%
fig = ggplot(df)
bar = geom_col(aes(x = 'sex', y = 'score', fill = 'sex'))

fig + bar +scale_fill_manual(['red','blue'])
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# > 색상 입력에는 이름이 정해진 색상들 뿐만 아니라 이미 설정된 C0, C1... 또는 hex code도 입력이 가능하다.

# %% [markdown]
# ### **B. `facet_warp()`
# ---

# %% [markdown]
# \- 예시1 : `facet_warp()`를 이용한 면분할 -- 반별로 면분할

# %%
df = pd.DataFrame({'sex':['male','female','male','female'],'score':[40,60,50,20],'class':['A','A','B','B']})
df
# Out:
#       sex  score class
# 0    male     40     A
# 1  female     60     A
# 2    male     50     B
# 3  female     20     B

# %%
ggplot(df) + geom_col(aes(x='sex',y='score',fill='sex')) + scale_fill_manual(['red','blue']) + facet_wrap('class')
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# > `class`별로 그래프의 면을 분할해서 표시

# %%
ggplot(df) + geom_col(aes(x = 'sex', y = 'score', fill = 'sex')) + scale_fill_manual(['red','blue'])  ## 지정해주지 않을 경우 합산하여 지정된다.
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# \- 예시2 : 성별로 면분할

# %%
df = pd.DataFrame({'sex':['male','female','male','female'],'score':[40,60,50,20],'class':['A','A','B','B']})
df
# Out:
#       sex  score class
# 0    male     40     A
# 1  female     60     A
# 2    male     50     B
# 3  female     20     B

# %%
ggplot(df) + geom_col(aes(x='class',y='score',fill='sex')) + facet_wrap('sex')
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## 4. 심슨의 역설

# %% [markdown]
# \- 버클리 대학교의 입학 데이터에서 gender bias가 존재한다는 주장

# %%
df=pd.read_csv("https://raw.githubusercontent.com/guebin/DV2022/master/posts/Simpson.csv",index_col=0,header=[0,1])\
.stack().stack().reset_index()\
.rename({'level_0':'department','level_1':'result','level_2':'gender',0:'count'},axis=1)
df
# Out:
#    department result  gender  count
# 0           A   fail  female     19
# 1           A   fail    male    314
# 2           A   pass  female     89
# 3           A   pass    male    511
# 4           B   fail  female      7
# 5           B   fail    male    208
# 6           B   pass  female     18
# 7           B   pass    male    352
# 8           C   fail  female    391
# 9           C   fail    male    204
# 10          C   pass  female    202
# 11          C   pass    male    121
# 12          D   fail  female    244
# 13          D   fail    male    279
# 14          D   pass  female    131
# 15          D   pass    male    138
# 16          E   fail  female    299
# 17          E   fail    male    137
# 18          E   pass  female     94
# 19          E   pass    male     54
# 20          F   fail  female    103
# 21          F   fail    male    149
# 22          F   pass  female    238
# 23          F   pass    male    224

# %% [markdown]
# ### **A. 시각화 1 : 전체 합격률 시각화 -- pandas 초보**

# %%
df.query('gender == "female" and result == "pass"')['count'].sum()
# Out:
# 772

# %% [markdown]
# > 여성 지원자 중 합격한 사람의 수

# %%
df.query('gender == "female"')['count'].sum()
# Out:
# 1835

# %% [markdown]
# > 총 여성 지원자 수

# %%
(df.query('gender == "female" and result == "pass"')['count'].sum()/df.query('gender == "female"')['count'].sum(),
 df.query('gender == "male" and result == "pass"')['count'].sum()/df.query('gender == "male"')['count'].sum())
# Out:
# (0.420708446866485, 0.5202526941657376)

# %%
tidydata_ = pd.DataFrame({'female' : df.query('gender == "female" and result == "pass"')['count'].sum()/df.query('gender == "female"')['count'].sum(),
                          'male' : df.query('gender == "male" and result == "pass"')['count'].sum()/df.query('gender == "male"')['count'].sum()})

tidydata_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-74aee3cdff88> in <cell line: 1>()
# ----> 1 tidydata_ = pd.DataFrame({'female' : df.query('gender == "female" and result == "pass"')['count'].sum()/df.query('gender == "female"')['count'].sum(),
#       2                           'male' : df.query('gender == "male" and result == "pass"')['count'].sum()/df.query('gender == "male"')['count'].sum()})
#       3
#       4 tidydata_
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# --> 493     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     494
#     495
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         # figure out the index, if necessary
#     117         if index is None:
# --> 118             index = _extract_index(arrays)
#     119         else:
#     120             index = ensure_index(index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     654
#     655         if not indexes and not raw_lengths:
# --> 656             raise ValueError("If using all scalar values, you must pass an index")
#     657
#     658         elif have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
tidydata = pd.DataFrame({'sex' : ['male', 'female'],
                         'rate' : [df.query('gender == "female" and result == "pass"')['count'].sum()/df.query('gender == "female"')['count'].sum(),
                                   df.query('gender == "male" and result == "pass"')['count'].sum()/df.query('gender == "male"')['count'].sum()]})

tidydata
# Out:
#       sex      rate
# 0    male  0.420708
# 1  female  0.520253

# %% [markdown]
# ### **B. 시각화 1 : 전체 합격률 시각화 -- pandas 고수**

# %% [markdown]
# \- 피벗 테이블을 만든다. (두 범주형 자료들을 나누는 것)

# %%
df.pivot_table(index='gender',columns='result',values='count',aggfunc=sum)
# Out:
# result  fail  pass
# gender
# female  1063   772
# male    1291  1400

# %%
df.pivot_table(index='gender',columns='result',values='count')    ## 집계함수의 디폴트 값이 mean이다
# Out:
# result        fail        pass
# gender
# female  177.166667  128.666667
# male    215.166667  233.333333

# %%
df
# Out:
#    department result  gender  count
# 0           A   fail  female     19
# 1           A   fail    male    314
# 2           A   pass  female     89
# 3           A   pass    male    511
# 4           B   fail  female      7
# 5           B   fail    male    208
# 6           B   pass  female     18
# 7           B   pass    male    352
# 8           C   fail  female    391
# 9           C   fail    male    204
# 10          C   pass  female    202
# 11          C   pass    male    121
# 12          D   fail  female    244
# 13          D   fail    male    279
# 14          D   pass  female    131
# 15          D   pass    male    138
# 16          E   fail  female    299
# 17          E   fail    male    137
# 18          E   pass  female     94
# 19          E   pass    male     54
# 20          F   fail  female    103
# 21          F   fail    male    149
# 22          F   pass  female    238
# 23          F   pass    male    224

# %%
df.pivot_table(index='gender',columns='result',values='count',aggfunc=sum)\
.assign(rate = lambda _df : _df['pass']/(_df['fail'] + _df['pass'])).reset_index()
# Out:
# result  gender  fail  pass      rate
# 0       female  1063   772  0.420708
# 1         male  1291  1400  0.520253

# %%
tidydata = df.pivot_table(index='gender',columns='result',values='count',aggfunc=sum).assign(rate = lambda _df : _df['pass']/(_df['fail'] + _df['pass'])).reset_index()

fig = ggplot(tidydata)
bar = geom_col(aes(x='gender',fill='gender',y='rate'))
fig+bar
# Out:
# <Figure Size: (640 x 480)>

# %%
df.pivot_table(index=['department'],columns=['result','gender'],values='count',aggfunc=sum)
# Out:
# result       fail        pass
# gender     female male female male
# department
# A              19  314     89  511
# B               7  208     18  352
# C             391  204    202  121
# D             244  279    131  138
# E             299  137     94   54
# F             103  149    238  224

# %%
df.pivot_table(index=['department'],columns=['result','gender'],values='count',aggfunc=sum).stack()\
.assign(rate = lambda _df: _df['pass']/(_df['fail'] + _df['pass']))\
.drop(['fail','pass'],axis=1)\
.reset_index()
