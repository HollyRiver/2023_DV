# %% [markdown]
# **오늘 한 내용은 왠만해선 다 알아두는 게 좋다.**

# %% [markdown]
# ## 1. import

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(3, 2))
df
# Out:
#           0         1
# 0  1.715680  0.327035
# 1 -0.931626  0.472884
# 2  1.902886 -1.643391

# %% [markdown]
# ## 2. Pandas 기본기능

# %% [markdown]
# ### A. 열의 이름 변경

# %% [markdown]
# \- df.columns에 대입

# %%
df.columns = ['A', 'B']
df
# Out:
#           A         B
# 0 -1.079852 -0.637533
# 1  0.759506  0.237517
# 2 -0.871811 -0.325153

# %% [markdown]
# \- df.set_axis()

# %%
df2 = pd.DataFrame(np.random.randn(5,3))
df2
# Out:
#           0         1         2
# 0 -0.639476  0.154820 -1.142040
# 1  1.092790 -0.140529  1.749416
# 2  0.497990  1.006000  0.133886
# 3  0.800762  0.915722  1.447229
# 4 -0.470032 -0.545448 -0.318221

# %%
df2 = df2.set_axis(['A','B','C'], axis = 1)
df2
# Out:
#           A         B         C
# 0 -0.639476  0.154820 -1.142040
# 1  1.092790 -0.140529  1.749416
# 2  0.497990  1.006000  0.133886
# 3  0.800762  0.915722  1.447229
# 4 -0.470032 -0.545448 -0.318221

# %%
df2.set_axis(['a','b','c','d','e'], axis = 0)
# Out:
#           0         1         2
# a -0.639476  0.154820 -1.142040
# b  1.092790 -0.140529  1.749416
# c  0.497990  1.006000  0.133886
# d  0.800762  0.915722  1.447229
# e -0.470032 -0.545448 -0.318221

# %% [markdown]
# \- df.rename()

# %%
df3 = pd.DataFrame(np.random.randn(5,3))
df3
# Out:
#           0         1         2
# 0 -0.237318 -0.851183  0.322254
# 1  0.983012  0.249586 -0.951911
# 2  0.712327  1.049104 -1.998271
# 3 -0.440946 -0.162180 -0.742113
# 4 -0.454311 -0.398484 -1.972987

# %%
df3.rename({0 : 'A'}, axis = 1) ## dictionary 형태로 지정
# Out:
#           A         1         2
# 0 -0.237318 -0.851183  0.322254
# 1  0.983012  0.249586 -0.951911
# 2  0.712327  1.049104 -1.998271
# 3 -0.440946 -0.162180 -0.742113
# 4 -0.454311 -0.398484 -1.972987

# %%
df3.rename(columns = {0 : 'A'})
# Out:
#           A         1         2
# 0  0.530369 -0.136149  1.122968
# 1  1.247519  0.814793  0.142766
# 2  0.114050 -0.821587  0.920281
# 3  0.459944  0.811753  1.373191
# 4 -1.138097  0.232429 -0.936851

# %% [markdown]
# ### B. 행의 이름 변경
#
# \- df.index에 대입

# %%
df = pd.DataFrame(np.random.randn(2,3))
df
# Out:
#           0         1         2
# 0  0.528203 -1.687762 -0.459782
# 1  0.224143 -1.367343  1.092839

# %%
df.index = [1, 2]
df
# Out:
#           0         1         2
# 1  0.528203 -1.687762 -0.459782
# 2  0.224143 -1.367343  1.092839

# %% [markdown]
# \- df.set_axis()

# %%
df = pd.DataFrame(np.random.randn(2,3))
df
# Out:
#           0         1         2
# 0 -0.454264 -0.475760 -0.237963
# 1 -1.744315 -1.026659  1.071473

# %%
df.set_axis(['1','2'], axis = 0)
# Out:
#           0         1         2
# 1 -0.454264 -0.475760 -0.237963
# 2 -1.744315 -1.026659  1.071473

# %% [markdown]
# \- df.rename()

# %%
df = pd.DataFrame(np.random.randn(2,3))
df
# Out:
#           0         1         2
# 0 -0.051285  1.185885  0.841335
# 1  0.118555  1.527457  0.544870

# %%
df.rename({0 : 'A'}, axis = 0)    ## default = 0
# Out:
#           0         1         2
# A -0.051285  1.185885  0.841335
# 1  0.118555  1.527457  0.544870

# %% [markdown]
# \- 임의의 열을 행이름으로 지정 | **이미 있던 열 하나를 인덱스로 잡고 싶을 시**

# %%
df = pd.DataFrame({'id':['2020-43052','2021-43053'], 'X1':[1,2],'X2':[2,3]})
df
# Out:
#            id  X1  X2
# 0  2020-43052   1   2
# 1  2021-43053   2   3

# %%
df.set_index('id')
# Out:
#             X1  X2
# id
# 2020-43052   1   2
# 2021-43053   2   3

# %% [markdown]
# ## \# A~B에 대한 연습문제

# %% [markdown]
# \- 데이터 load

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/FIFA23_official_data.csv')
df.head()
# Out:
#        ID             Name  Age  \
# 0  209658      L. Goretzka   27
# 1  212198  Bruno Fernandes   27
# 2  224334         M. Acuña   30
# 3  192985     K. De Bruyne   31
# 4  224232       N. Barella   25
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.net/players/209/658/23_60.png     Germany
# 1  https://cdn.sofifa.net/players/212/198/23_60.png    Portugal
# 2  https://cdn.sofifa.net/players/224/334/23_60.png   Argentina
# 3  https://cdn.sofifa.net/players/192/985/23_60.png     Belgium
# 4  https://cdn.sofifa.net/players/224/232/23_60.png       Italy
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.net/flags/de.png       87         88  FC Bayern München
# 1  https://cdn.sofifa.net/flags/pt.png       86         87  Manchester United
# 2  https://cdn.sofifa.net/flags/ar.png       85         85         Sevilla FC
# 3  https://cdn.sofifa.net/flags/be.png       91         91    Manchester City
# 4  https://cdn.sofifa.net/flags/it.png       86         89              Inter
#
#                                  Club Logo  ... Real Face  \
# 0   https://cdn.sofifa.net/teams/21/30.png  ...       Yes
# 1   https://cdn.sofifa.net/teams/11/30.png  ...       Yes
# 2  https://cdn.sofifa.net/teams/481/30.png  ...        No
# 3   https://cdn.sofifa.net/teams/10/30.png  ...       Yes
# 4   https://cdn.sofifa.net/teams/44/30.png  ...       Yes
#
#                       Position        Joined Loaned From  \
# 0  <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1  <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2    <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4  <span class="pos pos13">RCM   Sep 1, 2020         NaN
#
#    Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 0                  2026   189cm    82kg          €157M        8.0
# 1                  2026   179cm    69kg          €155M        8.0
# 2                  2024   172cm    69kg         €97.7M       19.0
# 3                  2025   181cm    70kg        €198.9M       17.0
# 4                  2026   172cm    68kg        €154.4M       23.0
#
#   Best Overall Rating
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# `# 예제1`: 열의 이름 출력하고, 열의 이름중 공백(` `)이 있을 경우 언더바(`_`) 로 바꾸자.

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause', 'Kit Number', 'Best Overall Rating'],
#       dtype='object')

# %% [markdown]
# \- 1. df.columns에 직접 대입

# %%
[i.replace(' ', '_') for i in df.columns] ## str.replace(,)특정 문자열을 특정 문자열로 바꾸는 함수
# Out:
# ['ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club_Logo',
#  'Value',
#  'Wage',
#  'Special',
#  'Preferred_Foot',
#  'International_Reputation',
#  'Weak_Foot',
#  'Skill_Moves',
#  'Work_Rate',
#  'Body_Type',
#  'Real_Face',
#  'Position',
#  'Joined',
#  'Loaned_From',
#  'Contract_Valid_Until',
#  'Height',
#  'Weight',
#  'Release_Clause',
#  'Kit_Number',
#  'Best_Overall_Rating']

# %%
temp = df
temp.columns = [i.replace(' ', '_') for i in df.columns]

# %%
temp.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club_Logo', 'Value', 'Wage', 'Special',
#        'Preferred_Foot', 'International_Reputation', 'Weak_Foot',
#        'Skill_Moves', 'Work_Rate', 'Body_Type', 'Real_Face', 'Position',
#        'Joined', 'Loaned_From', 'Contract_Valid_Until', 'Height', 'Weight',
#        'Release_Clause', 'Kit_Number', 'Best_Overall_Rating'],
#       dtype='object')

# %% [markdown]
# \- 2. set_axis() 이용

# %%
temp2 = [s.replace()]

# %% [markdown]
# \- 3. rename() 이용(안중요함)

# %%
temp3 = df

dic = {i:i.replace(' ','_') for i in df.columns}
temp3.rename(dic, axis = 1).columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club_Logo', 'Value', 'Wage', 'Special',
#        'Preferred_Foot', 'International_Reputation', 'Weak_Foot',
#        'Skill_Moves', 'Work_Rate', 'Body_Type', 'Real_Face', 'Position',
#        'Joined', 'Loaned_From', 'Contract_Valid_Until', 'Height', 'Weight',
#        'Release_Clause', 'Kit_Number', 'Best_Overall_Rating'],
#       dtype='object')

# %% [markdown]
# `예제2`: ID를 row-index로 지정하라.

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause', 'Kit Number', 'Best Overall Rating'],
#       dtype='object')

# %% [markdown]
# 1) 직접지정

# %%
df2 = df
df2.index = df.ID
df2.index
# Out:
# Int64Index([209658, 212198, 224334, 192985, 224232, 212622, 197445, 187961,
#             208333, 210514,
#             ...
#             256879, 269546, 267647, 253186, 267461, 269526, 267946, 270567,
#             256624, 256376],
#            dtype='int64', name='ID', length=17660)

# %% [markdown]
# 2) set_axis()

# %%
df3 = df
df3 = df3.set_axis(df.ID)   ## default : axis = 0
df3.index
# Out:
# Int64Index([209658, 212198, 224334, 192985, 224232, 212622, 197445, 187961,
#             208333, 210514,
#             ...
#             256879, 269546, 267647, 253186, 267461, 269526, 267946, 270567,
#             256624, 256376],
#            dtype='int64', name='ID', length=17660)

# %%
df4 = df
df4 = df4.set_index('ID')
df4.index
# Out:
# Int64Index([209658, 212198, 224334, 192985, 224232, 212622, 197445, 187961,
#             208333, 210514,
#             ...
#             256879, 269546, 267647, 253186, 267461, 269526, 267946, 270567,
#             256624, 256376],
#            dtype='int64', name='ID', length=17660)

# %% [markdown]
# ### C. ```pd.T```

# %% [markdown]
# \- ```df.T```를 이용하여 데이터를 살피면 편리함

# %%
df.T.loc[:,:3]
# Out:
#                                                                          0  \
# ID                                                                  209658
# Name                                                           L. Goretzka
# Age                                                                     27
# Photo                     https://cdn.sofifa.net/players/209/658/23_60.png
# Nationality                                                        Germany
# Flag                                   https://cdn.sofifa.net/flags/de.png
# Overall                                                                 87
# Potential                                                               88
# Club                                                     FC Bayern München
# Club Logo                           https://cdn.sofifa.net/teams/21/30.png
# Value                                                                 €91M
# Wage                                                                 €115K
# Special                                                               2312
# Preferred Foot                                                       Right
# International Reputation                                               4.0
# Weak Foot                                                              4.0
# Skill Moves                                                            3.0
# Work Rate                                                     High/ Medium
# Body Type                                                           Unique
# Real Face                                                              Yes
# Position                                       <span class="pos pos28">SUB
# Joined                                                         Jul 1, 2018
# Loaned From                                                            NaN
# Contract Valid Until                                                  2026
# Height                                                               189cm
# Weight                                                                82kg
# Release Clause                                                       €157M
# Kit Number                                                             8.0
# Best Overall Rating                                                    NaN
#
#                                                                          1  \
# ID                                                                  212198
# Name                                                       Bruno Fernandes
# Age                                                                     27
# Photo                     https://cdn.sofifa.net/players/212/198/23_60.png
# Nationality                                                       Portugal
# Flag                                   https://cdn.sofifa.net/flags/pt.png
# Overall                                                                 86
# Potential                                                               87
# Club                                                     Manchester United
# Club Logo                           https://cdn.sofifa.net/teams/11/30.png
# Value                                                               €78.5M
# Wage                                                                 €190K
# Special                                                               2305
# Preferred Foot                                                       Right
# International Reputation                                               3.0
# Weak Foot                                                              3.0
# Skill Moves                                                            4.0
# Work Rate                                                       High/ High
# Body Type                                                           Unique
# Real Face                                                              Yes
# Position                                       <span class="pos pos15">LCM
# Joined                                                        Jan 30, 2020
# Loaned From                                                            NaN
# Contract Valid Until                                                  2026
# Height                                                               179cm
# Weight                                                                69kg
# Release Clause                                                       €155M
# Kit Number                                                             8.0
# Best Overall Rating                                                    NaN
#
#                                                                          2  \
# ID                                                                  224334
# Name                                                              M. Acuña
# Age                                                                     30
# Photo                     https://cdn.sofifa.net/players/224/334/23_60.png
# Nationality                                                      Argentina
# Flag                                   https://cdn.sofifa.net/flags/ar.png
# Overall                                                                 85
# Potential                                                               85
# Club                                                            Sevilla FC
# Club Logo                          https://cdn.sofifa.net/teams/481/30.png
# Value                                                               €46.5M
# Wage                                                                  €46K
# Special                                                               2303
# Preferred Foot                                                        Left
# International Reputation                                               2.0
# Weak Foot                                                              3.0
# Skill Moves                                                            3.0
# Work Rate                                                       High/ High
# Body Type                                                 Stocky (170-185)
# Real Face                                                               No
# Position                                         <span class="pos pos7">LB
# Joined                                                        Sep 14, 2020
# Loaned From                                                            NaN
# Contract Valid Until                                                  2024
# Height                                                               172cm
# Weight                                                                69kg
# Release Clause                                                      €97.7M
# Kit Number                                                            19.0
# Best Overall Rating                                                    NaN
#
#                                                                          3
# ID                                                                  192985
# Name                                                          K. De Bruyne
# Age                                                                     31
# Photo                     https://cdn.sofifa.net/players/192/985/23_60.png
# Nationality                                                        Belgium
# Flag                                   https://cdn.sofifa.net/flags/be.png
# Overall                                                                 91
# Potential                                                               91
# Club                                                       Manchester City
# Club Logo                           https://cdn.sofifa.net/teams/10/30.png
# Value                                                              €107.5M
# Wage                                                                 €350K
# Special                                                               2303
# Preferred Foot                                                       Right
# International Reputation                                               4.0
# Weak Foot                                                              5.0
# Skill Moves                                                            4.0
# Work Rate                                                       High/ High
# Body Type                                                           Unique
# Real Face                                                              Yes
# Position                                       <span class="pos pos13">RCM
# Joined                                                        Aug 30, 2015
# Loaned From                                                            NaN
# Contract Valid Until                                                  2025
# Height                                                               181cm
# Weight                                                                70kg
# Release Clause                                                     €198.9M
# Kit Number                                                            17.0
# Best Overall Rating                                                    NaN

# %% [markdown]
# \- 출력옵션 조정

# %%
pd.options.display.max_rows = 10
display(df.T.iloc[:, :3])
pd.reset_option('display.max_rows')   ## 디폴트 옵션으로 변경
# Out:
#                                                                     0  \
# ID                                                             209658
# Name                                                      L. Goretzka
# Age                                                                27
# Photo                https://cdn.sofifa.net/players/209/658/23_60.png
# Nationality                                                   Germany
# ...                                                               ...
# Height                                                          189cm
# Weight                                                           82kg
# Release Clause                                                  €157M
# Kit Number                                                        8.0
# Best Overall Rating                                               NaN
#
#                                                                     1  \
# ID                                                             212198
# Name                                                  Bruno Fernandes
# Age                                                                27
# Photo                https://cdn.sofifa.net/players/212/198/23_60.png
# Nationality                                                  Portugal
# ...                                                               ...
# Height                                                          179cm
# Weight                                                           69kg
# Release Clause                                                  €155M
# Kit Number                                                        8.0
# Best Overall Rating                                               NaN
#
#                                                                     2
# ID                                                             224334
# Name                                                         M. Acuña
# Age                                                                30
# Photo                https://cdn.sofifa.net/players/224/334/23_60.png
# Nationality                                                 Argentina
# ...                                                               ...
# Height                                                          172cm
# Weight                                                           69kg
# Release Clause                                                 €97.7M
# Kit Number                                                       19.0
# Best Overall Rating                                               NaN
#
# [29 rows x 3 columns]

# %% [markdown]
# > 여기선 설명을 위해 줄이는 옵션을 사용했지만, 보통은 늘려서 사용함.

# %% [markdown]
# ### D. ```df.dtypes```, ```s,dtype```

# %% [markdown]
# \- ```df.dtypes```

# %%
df.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Photo                        object
# Nationality                  object
# Flag                         object
# Overall                       int64
# Potential                     int64
# Club                         object
# Club Logo                    object
# Value                        object
# Wage                         object
# Special                       int64
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Body Type                    object
# Real Face                    object
# Position                     object
# Joined                       object
# Loaned From                  object
# Contract Valid Until         object
# Height                       object
# Weight                       object
# Release Clause               object
# Kit Number                  float64
# Best Overall Rating          object
# dtype: object

# %% [markdown]
# > object : string이라고 생각해도 무방. 범주형 자료.

# %% [markdown]
# \- ```s.dtype``` Series에 붙여 사용

# %%
df.Name.dtype   ## 한 행의 데이터 타입만을 산출
# Out:
# dtype('O')

# %%
df.Name.dtype == np.object_
# Out:
# True

# %%
df.Age.dtype == np.int64
# Out:
# True

# %%
df['International Reputation'].dtype == np.float64
# Out:
# True

# %% [markdown]
# `# 예제`: `df`에서 `int64` 자료형만 출력

# %% [markdown]
# (풀이 1) 직접 뽑음

# %%
pd.Series(list(df.dtypes))
# Out:
# 0       int64
# 1      object
# 2       int64
# 3      object
# 4      object
# 5      object
# 6       int64
# 7       int64
# 8      object
# 9      object
# 10     object
# 11     object
# 12      int64
# 13     object
# 14    float64
# 15    float64
# 16    float64
# 17     object
# 18     object
# 19     object
# 20     object
# 21     object
# 22     object
# 23     object
# 24     object
# 25     object
# 26     object
# 27    float64
# 28     object
# dtype: object

# %%
df.iloc[:, [0,2,6,7,12]]
# Out:
#            ID  Age  Overall  Potential  Special
# 0      209658   27       87         88     2312
# 1      212198   27       86         87     2305
# 2      224334   30       85         85     2303
# 3      192985   31       91         91     2303
# 4      224232   25       86         89     2296
# ...       ...  ...      ...        ...      ...
# 17655  269526   19       48         61      762
# 17656  267946   17       48         64      761
# 17657  270567   25       51         56      759
# 17658  256624   18       50         65      758
# 17659  256376   20       50         61      749
#
# [17660 rows x 5 columns]

# %% [markdown]
# (풀이 2) 리스트 컴프리핸션 이용

# %%
df.loc[:, [o == np.int64 for o in df.dtypes]]
# Out:
#            ID  Age  Overall  Potential  Special
# 0      209658   27       87         88     2312
# 1      212198   27       86         87     2305
# 2      224334   30       85         85     2303
# 3      192985   31       91         91     2303
# 4      224232   25       86         89     2296
# ...       ...  ...      ...        ...      ...
# 17655  269526   19       48         61      762
# 17656  267946   17       48         64      761
# 17657  270567   25       51         56      759
# 17658  256624   18       50         65      758
# 17659  256376   20       50         61      749
#
# [17660 rows x 5 columns]

# %% [markdown]
# ### E. ```df.sort_values()```
#
# \- 순서대로 정렬

# %%
df.sort_values('Age')   ## 오름차순 정렬
# Out:
#            ID                Name  Age  \
# 17636  263636       22 D. Oncescu   15
# 13712  271072            E. Topcu   16
# 13078  259442  22 R. van den Berg   16
# 11257  266205          22 Y. Koré   16
# 11278  261873       21 H. Kumagai   16
# ...       ...                 ...  ...
# 16311  254196     21 L. Fernández   42
# 16036  216692          S. Torrico   42
# 17257     645     17 D. Andersson   43
# 15375    1179           G. Buffon   44
# 15272  254704         22 K. Miura   54
#
#                                                   Photo          Nationality  \
# 17636  https://cdn.sofifa.net/players/263/636/22_60.png              Romania
# 13712  https://cdn.sofifa.net/players/271/072/23_60.png  Republic of Ireland
# 13078  https://cdn.sofifa.net/players/259/442/22_60.png          Netherlands
# 11257  https://cdn.sofifa.net/players/266/205/22_60.png               France
# 11278  https://cdn.sofifa.net/players/261/873/21_60.png                Japan
# ...                                                 ...                  ...
# 16311  https://cdn.sofifa.net/players/254/196/21_60.png             Colombia
# 16036  https://cdn.sofifa.net/players/216/692/23_60.png            Argentina
# 17257  https://cdn.sofifa.net/players/000/645/17_60.png               Sweden
# 15375  https://cdn.sofifa.net/players/001/179/23_60.png                Italy
# 15272  https://cdn.sofifa.net/players/254/704/22_60.png                Japan
#
#                                       Flag  Overall  Potential  \
# 17636  https://cdn.sofifa.net/flags/ro.png       50         72
# 13712  https://cdn.sofifa.net/flags/ie.png       48         58
# 13078  https://cdn.sofifa.net/flags/nl.png       60         81
# 11257  https://cdn.sofifa.net/flags/fr.png       59         74
# 11278  https://cdn.sofifa.net/flags/jp.png       52         70
# ...                                    ...      ...        ...
# 16311  https://cdn.sofifa.net/flags/co.png       61         61
# 16036  https://cdn.sofifa.net/flags/ar.png       72         72
# 17257  https://cdn.sofifa.net/flags/se.png       57         57
# 15375  https://cdn.sofifa.net/flags/it.png       79         79
# 15272  https://cdn.sofifa.net/flags/jp.png       56         56
#
#                            Club                                   Club Logo  \
# 17636  FC Dinamo 1948 Bucureşti  https://cdn.sofifa.net/teams/100757/30.png
# 13712           Drogheda United    https://cdn.sofifa.net/teams/1572/30.png
# 13078                PEC Zwolle    https://cdn.sofifa.net/teams/1914/30.png
# 11257                  Paris FC  https://cdn.sofifa.net/teams/111817/30.png
# 11278            Vegalta Sendai  https://cdn.sofifa.net/teams/112836/30.png
# ...                         ...                                         ...
# 16311  Sociedad Deportiva Aucas  https://cdn.sofifa.net/teams/110987/30.png
# 16036    San Lorenzo de Almagro    https://cdn.sofifa.net/teams/1013/30.png
# 17257           Helsingborgs IF     https://cdn.sofifa.net/teams/432/30.png
# 15375                     Parma      https://cdn.sofifa.net/teams/50/30.png
# 15272               Yokohama FC  https://cdn.sofifa.net/teams/113197/30.png
#
#        ... Real Face                     Position        Joined Loaned From  \
# 17636  ...        No  <span class="pos pos29">RES   Jun 1, 2021         NaN
# 13712  ...        No  <span class="pos pos29">RES   Jul 8, 2022         NaN
# 13078  ...        No  <span class="pos pos29">RES  May 24, 2020         NaN
# 11257  ...        No  <span class="pos pos29">RES  Aug 11, 2022         NaN
# 11278  ...        No  <span class="pos pos29">RES  Apr 16, 2021         NaN
# ...    ...       ...                          ...           ...         ...
# 16311  ...        No  <span class="pos pos28">SUB  Jan 29, 2018         NaN
# 16036  ...        No    <span class="pos pos0">GK  Apr 25, 2013         NaN
# 17257  ...        No  <span class="pos pos28">SUB  Apr 21, 2016         NaN
# 15375  ...       Yes    <span class="pos pos0">GK   Jul 1, 2021         NaN
# 15272  ...        No  <span class="pos pos29">RES   Jul 1, 2005         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 17636                  2025   190cm    77kg          €306K       34.0
# 13712                  2022   183cm    65kg          €175K       20.0
# 13078                  2024   190cm    73kg          €1.8M       33.0
# 11257                  2025   187cm    75kg          €1.1M       34.0
# 11278                  2023   174cm    64kg          €375K       48.0
# ...                     ...     ...     ...            ...        ...
# 16311                  2024   187cm    82kg           €75K        1.0
# 16036                  2022   183cm    84kg          €375K       12.0
# 17257                  2022   187cm    85kg            NaN       39.0
# 15375                  2024   192cm    92kg            €3M        1.0
# 15272                  2022   177cm    72kg            NaN       11.0
#
#       Best Overall Rating
# 17636                 NaN
# 13712                 NaN
# 13078                 NaN
# 11257                 NaN
# 11278                 NaN
# ...                   ...
# 16311                 NaN
# 16036                 NaN
# 17257                 NaN
# 15375                 NaN
# 15272                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# \- 내림차순으로 정렬

# %%
df.sort_values('Age', ascending = False)  ## default : ascending = True
# Out:
#            ID              Name  Age  \
# 15272  254704       22 K. Miura   54
# 15375    1179         G. Buffon   44
# 17257     645   17 D. Andersson   43
# 16036  216692        S. Torrico   42
# 16311  254196   21 L. Fernández   42
# ...       ...               ...  ...
# 17360  261023       21 H. Broun   16
# 15536  263639       22 M. Pavel   16
# 11398  256405  21 W. Essanoussi   16
# 15030  270594        T. Walczak   16
# 17636  263636     22 D. Oncescu   15
#
#                                                   Photo  Nationality  \
# 15272  https://cdn.sofifa.net/players/254/704/22_60.png        Japan
# 15375  https://cdn.sofifa.net/players/001/179/23_60.png        Italy
# 17257  https://cdn.sofifa.net/players/000/645/17_60.png       Sweden
# 16036  https://cdn.sofifa.net/players/216/692/23_60.png    Argentina
# 16311  https://cdn.sofifa.net/players/254/196/21_60.png     Colombia
# ...                                                 ...          ...
# 17360  https://cdn.sofifa.net/players/261/023/21_60.png     Scotland
# 15536  https://cdn.sofifa.net/players/263/639/22_60.png      Romania
# 11398  https://cdn.sofifa.net/players/256/405/21_60.png  Netherlands
# 15030  https://cdn.sofifa.net/players/270/594/23_60.png       Poland
# 17636  https://cdn.sofifa.net/players/263/636/22_60.png      Romania
#
#                                           Flag  Overall  Potential  \
# 15272      https://cdn.sofifa.net/flags/jp.png       56         56
# 15375      https://cdn.sofifa.net/flags/it.png       79         79
# 17257      https://cdn.sofifa.net/flags/se.png       57         57
# 16036      https://cdn.sofifa.net/flags/ar.png       72         72
# 16311      https://cdn.sofifa.net/flags/co.png       61         61
# ...                                        ...      ...        ...
# 17360  https://cdn.sofifa.net/flags/gb-sct.png       52         72
# 15536      https://cdn.sofifa.net/flags/ro.png       51         69
# 11398      https://cdn.sofifa.net/flags/nl.png       59         75
# 15030      https://cdn.sofifa.net/flags/pl.png       54         68
# 17636      https://cdn.sofifa.net/flags/ro.png       50         72
#
#                            Club                                   Club Logo  \
# 15272               Yokohama FC  https://cdn.sofifa.net/teams/113197/30.png
# 15375                     Parma      https://cdn.sofifa.net/teams/50/30.png
# 17257           Helsingborgs IF     https://cdn.sofifa.net/teams/432/30.png
# 16036    San Lorenzo de Almagro    https://cdn.sofifa.net/teams/1013/30.png
# 16311  Sociedad Deportiva Aucas  https://cdn.sofifa.net/teams/110987/30.png
# ...                         ...                                         ...
# 17360                Kilmarnock      https://cdn.sofifa.net/teams/82/30.png
# 15536  FC Dinamo 1948 Bucureşti  https://cdn.sofifa.net/teams/100757/30.png
# 11398                 VVV-Venlo  https://cdn.sofifa.net/teams/100651/30.png
# 15030               Wisła Płock    https://cdn.sofifa.net/teams/1569/30.png
# 17636  FC Dinamo 1948 Bucureşti  https://cdn.sofifa.net/teams/100757/30.png
#
#        ... Real Face                     Position        Joined Loaned From  \
# 15272  ...        No  <span class="pos pos29">RES   Jul 1, 2005         NaN
# 15375  ...       Yes    <span class="pos pos0">GK   Jul 1, 2021         NaN
# 17257  ...        No  <span class="pos pos28">SUB  Apr 21, 2016         NaN
# 16036  ...        No    <span class="pos pos0">GK  Apr 25, 2013         NaN
# 16311  ...        No  <span class="pos pos28">SUB  Jan 29, 2018         NaN
# ...    ...       ...                          ...           ...         ...
# 17360  ...        No  <span class="pos pos29">RES  Sep 17, 2020         NaN
# 15536  ...        No  <span class="pos pos29">RES   Jul 1, 2021         NaN
# 11398  ...        No  <span class="pos pos29">RES   Jul 1, 2019         NaN
# 15030  ...        No  <span class="pos pos29">RES   Sep 7, 2021         NaN
# 17636  ...        No  <span class="pos pos29">RES   Jun 1, 2021         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 15272                  2022   177cm    72kg            NaN       11.0
# 15375                  2024   192cm    92kg            €3M        1.0
# 17257                  2022   187cm    85kg            NaN       39.0
# 16036                  2022   183cm    84kg          €375K       12.0
# 16311                  2024   187cm    82kg           €75K        1.0
# ...                     ...     ...     ...            ...        ...
# 17360                  2022   182cm    70kg          €523K       40.0
# 15536                  2023   178cm    66kg          €277K       77.0
# 11398                  2022   178cm    70kg          €1.1M       24.0
# 15030                  2023   191cm    88kg          €494K       99.0
# 17636                  2025   190cm    77kg          €306K       34.0
#
#       Best Overall Rating
# 15272                 NaN
# 15375                 NaN
# 17257                 NaN
# 16036                 NaN
# 16311                 NaN
# ...                   ...
# 17360                 NaN
# 15536                 NaN
# 11398                 NaN
# 15030                 NaN
# 17636                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# \- 능력치가 좋은 순서대로 정렬

# %%
df.sort_values(by = 'Overall', ascending = False)    ## 수가 높을수록 위로 가니까, by 생략해도 됨.
# Out:
#            ID               Name  Age  \
# 41     188545     R. Lewandowski   33
# 124    165153         K. Benzema   34
# 3      192985       K. De Bruyne   31
# 56     158023           L. Messi   35
# 75     231747          K. Mbappé   23
# ...       ...                ...  ...
# 15513  266751    22 Jung Ho Yeon   20
# 16215  268279     22 J. Looschen   24
# 16042  255283  20 Kim Yeong Geun   22
# 14634  269038   22 Zhang Wenxuan   16
# 17618  168933       07 I. Paskov   33
#
#                                                   Photo     Nationality  \
# 41     https://cdn.sofifa.net/players/188/545/23_60.png          Poland
# 124    https://cdn.sofifa.net/players/165/153/23_60.png          France
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 56     https://cdn.sofifa.net/players/158/023/23_60.png       Argentina
# 75     https://cdn.sofifa.net/players/231/747/23_60.png          France
# ...                                                 ...             ...
# 15513  https://cdn.sofifa.net/players/266/751/22_60.png  Korea Republic
# 16215  https://cdn.sofifa.net/players/268/279/22_60.png         Germany
# 16042  https://cdn.sofifa.net/players/255/283/20_60.png  Korea Republic
# 14634  https://cdn.sofifa.net/players/269/038/22_60.png        China PR
# 17618  https://cdn.sofifa.net/players/168/933/07_60.png        Bulgaria
#
#                                       Flag  Overall  Potential  \
# 41     https://cdn.sofifa.net/flags/pl.png       91         91
# 124    https://cdn.sofifa.net/flags/fr.png       91         91
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 56     https://cdn.sofifa.net/flags/ar.png       91         91
# 75     https://cdn.sofifa.net/flags/fr.png       91         95
# ...                                    ...      ...        ...
# 15513  https://cdn.sofifa.net/flags/kr.png       45         53
# 16215  https://cdn.sofifa.net/flags/de.png       44         47
# 16042  https://cdn.sofifa.net/flags/kr.png       44         49
# 14634  https://cdn.sofifa.net/flags/cn.png       44         59
# 17618  https://cdn.sofifa.net/flags/bg.png       43         42
#
#                       Club                                   Club Logo  ...  \
# 41            FC Barcelona     https://cdn.sofifa.net/teams/241/30.png  ...
# 124         Real Madrid CF     https://cdn.sofifa.net/teams/243/30.png  ...
# 3          Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 56     Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# 75     Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# ...                    ...                                         ...  ...
# 15513           GwangJu FC  https://cdn.sofifa.net/teams/112258/30.png  ...
# 16215            SV Meppen  https://cdn.sofifa.net/teams/110597/30.png  ...
# 16042         Gyeongnam FC  https://cdn.sofifa.net/teams/111588/30.png  ...
# 14634         Guangzhou FC  https://cdn.sofifa.net/teams/111839/30.png  ...
# 17618                  NaN         https://cdn.sofifa.net/flags/bg.png  ...
#
#       Real Face                     Position        Joined Loaned From  \
# 41          Yes   <span class="pos pos25">ST  Jul 18, 2022         NaN
# 124         Yes   <span class="pos pos21">CF   Jul 9, 2009         NaN
# 3           Yes  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 56          Yes   <span class="pos pos23">RW  Aug 10, 2021         NaN
# 75          Yes   <span class="pos pos25">ST   Jul 1, 2018         NaN
# ...         ...                          ...           ...         ...
# 15513        No  <span class="pos pos29">RES  Jan 20, 2022         NaN
# 16215        No  <span class="pos pos29">RES  Mar 19, 2022         NaN
# 16042        No  <span class="pos pos29">RES   Jan 9, 2020         NaN
# 14634        No  <span class="pos pos29">RES   May 1, 2022         NaN
# 17618       NaN  <span class="pos pos28">SUB           NaN         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 41                     2025   185cm    81kg        €172.2M        9.0
# 124                    2023   185cm    81kg        €131.2M        9.0
# 3                      2025   181cm    70kg        €198.9M       17.0
# 56                     2023   169cm    67kg         €99.9M       30.0
# 75                     2025   182cm    73kg        €366.7M        7.0
# ...                     ...     ...     ...            ...        ...
# 15513                  2026   180cm    73kg          €145K       23.0
# 16215                  2026   178cm    78kg           €92K       42.0
# 16042                  2020   174cm    71kg           €53K       43.0
# 14634                  2022   175cm    70kg          €239K       29.0
# 17618                   NaN   184cm    79kg            NaN       24.0
#
#       Best Overall Rating
# 41                    NaN
# 124                   NaN
# 3                     NaN
# 56                    NaN
# 75                    NaN
# ...                   ...
# 15513                 NaN
# 16215                 NaN
# 16042                 NaN
# 14634                 NaN
# 17618                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# ### F. ```df.info()```
#
# 시험에는 절대 안 낼 거지만 매우 중요한 것

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17660 entries, 0 to 17659
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17660 non-null  int64
#  1   Name                      17660 non-null  object
#  2   Age                       17660 non-null  int64
#  3   Photo                     17660 non-null  object
#  4   Nationality               17660 non-null  object
#  5   Flag                      17660 non-null  object
#  6   Overall                   17660 non-null  int64
#  7   Potential                 17660 non-null  int64
#  8   Club                      17449 non-null  object
#  9   Club Logo                 17660 non-null  object
#  10  Value                     17660 non-null  object
#  11  Wage                      17660 non-null  object
#  12  Special                   17660 non-null  int64
#  13  Preferred Foot            17660 non-null  object
#  14  International Reputation  17660 non-null  float64
#  15  Weak Foot                 17660 non-null  float64
#  16  Skill Moves               17660 non-null  float64
#  17  Work Rate                 17660 non-null  object
#  18  Body Type                 17622 non-null  object
#  19  Real Face                 17622 non-null  object
#  20  Position                  17625 non-null  object
#  21  Joined                    16562 non-null  object
#  22  Loaned From               694 non-null    object
#  23  Contract Valid Until      17299 non-null  object
#  24  Height                    17660 non-null  object
#  25  Weight                    17660 non-null  object
#  26  Release Clause            16509 non-null  object
#  27  Kit Number                17625 non-null  float64
#  28  Best Overall Rating       21 non-null     object
# dtypes: float64(4), int64(5), object(20)
# memory usage: 3.9+ MB

# %% [markdown]
# > data들의 현황을 한눈에 파악하기 좋다.

# %%
df.iloc[:, [28]].sort_values('Best Overall Rating')
# Out:
#                           Best Overall Rating
# 13299  <span class="bp3-tag p p-54">54</span>
# 14366  <span class="bp3-tag p p-56">56</span>
# 16779  <span class="bp3-tag p p-58">58</span>
# 16968  <span class="bp3-tag p p-58">58</span>
# 16835  <span class="bp3-tag p p-59">59</span>
# ...                                       ...
# 17655                                     NaN
# 17656                                     NaN
# 17657                                     NaN
# 17658                                     NaN
# 17659                                     NaN
#
# [17660 rows x 1 columns]

# %% [markdown]
# ### G. ```df.isna()```

# %% [markdown]
# \- 열별로 결측치 카운트

# %%
df.isna()   ## NaN 값이 있다면 True 산출
# Out:
#           ID   Name    Age  Photo  Nationality   Flag  Overall  Potential  \
# 0      False  False  False  False        False  False    False      False
# 1      False  False  False  False        False  False    False      False
# 2      False  False  False  False        False  False    False      False
# 3      False  False  False  False        False  False    False      False
# 4      False  False  False  False        False  False    False      False
# ...      ...    ...    ...    ...          ...    ...      ...        ...
# 17655  False  False  False  False        False  False    False      False
# 17656  False  False  False  False        False  False    False      False
# 17657  False  False  False  False        False  False    False      False
# 17658  False  False  False  False        False  False    False      False
# 17659  False  False  False  False        False  False    False      False
#
#         Club  Club Logo  ...  Real Face  Position  Joined  Loaned From  \
# 0      False      False  ...      False     False   False         True
# 1      False      False  ...      False     False   False         True
# 2      False      False  ...      False     False   False         True
# 3      False      False  ...      False     False   False         True
# 4      False      False  ...      False     False   False         True
# ...      ...        ...  ...        ...       ...     ...          ...
# 17655  False      False  ...      False     False   False         True
# 17656  False      False  ...      False     False   False         True
# 17657  False      False  ...      False     False   False         True
# 17658  False      False  ...      False     False   False         True
# 17659  False      False  ...      False     False   False         True
#
#        Contract Valid Until  Height  Weight  Release Clause  Kit Number  \
# 0                     False   False   False           False       False
# 1                     False   False   False           False       False
# 2                     False   False   False           False       False
# 3                     False   False   False           False       False
# 4                     False   False   False           False       False
# ...                     ...     ...     ...             ...         ...
# 17655                 False   False   False           False       False
# 17656                 False   False   False           False       False
# 17657                 False   False   False           False       False
# 17658                 False   False   False           False       False
# 17659                 False   False   False           False       False
#
#        Best Overall Rating
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ...                    ...
# 17655                 True
# 17656                 True
# 17657                 True
# 17658                 True
# 17659                 True
#
# [17660 rows x 29 columns]

# %%
df.isna().sum(axis = 0)   ## default : axis = 0
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          211
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                  0
# International Reputation        0
# Weak Foot                       0
# Skill Moves                     0
# Work Rate                       0
# Body Type                      38
# Real Face                      38
# Position                       35
# Joined                       1098
# Loaned From                 16966
# Contract Valid Until          361
# Height                          0
# Weight                          0
# Release Clause               1151
# Kit Number                     35
# Best Overall Rating         17639
# dtype: int64

# %%
arr = np.array([(True, False), (True, False), (False, True)])
arr
# Out:
# array([[ True, False],
#        [ True, False],
#        [False,  True]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.sum(axis = 0) ## 열별로 합
# Out:
# array([2, 1])

# %%
arr.sum(axis = 1)   ## 행별로 합
# Out:
# array([1, 1, 1])

# %% [markdown]
# \- 예시2 : 결측치가 50% 이상인 열 출력

# %%
len(df) ## 전체 행의 갯수
# Out:
# 17660

# %%
df.isna().sum() / len(df)   ## <- pd.Series
# Out:
# ID                          0.000000
# Name                        0.000000
# Age                         0.000000
# Photo                       0.000000
# Nationality                 0.000000
# Flag                        0.000000
# Overall                     0.000000
# Potential                   0.000000
# Club                        0.011948
# Club Logo                   0.000000
# Value                       0.000000
# Wage                        0.000000
# Special                     0.000000
# Preferred Foot              0.000000
# International Reputation    0.000000
# Weak Foot                   0.000000
# Skill Moves                 0.000000
# Work Rate                   0.000000
# Body Type                   0.002152
# Real Face                   0.002152
# Position                    0.001982
# Joined                      0.062174
# Loaned From                 0.960702
# Contract Valid Until        0.020442
# Height                      0.000000
# Weight                      0.000000
# Release Clause              0.065176
# Kit Number                  0.001982
# Best Overall Rating         0.998811
# dtype: float64

# %%
df.loc[:, (df.isna().sum() / len(df)) > 0.5]
# Out:
#       Loaned From Best Overall Rating
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
# ...           ...                 ...
# 17655         NaN                 NaN
# 17656         NaN                 NaN
# 17657         NaN                 NaN
# 17658         NaN                 NaN
# 17659         NaN                 NaN
#
# [17660 rows x 2 columns]

# %% [markdown]
# ### H. ```df.drop()```
# \- 예시1 : [0,1,2,3] 행을 drop

# %%
df.drop([0,1,2,3])
## df.drop([0,1,2,3], axis = 0)
# Out:
#            ID             Name  Age  \
# 4      224232       N. Barella   25
# 5      212622       J. Kimmich   27
# 6      197445         D. Alaba   30
# 7      187961      22 Paulinho   32
# 8      208333           E. Can   28
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# 5      https://cdn.sofifa.net/players/212/622/23_60.png         Germany
# 6      https://cdn.sofifa.net/players/197/445/23_60.png         Austria
# 7      https://cdn.sofifa.net/players/187/961/22_60.png          Brazil
# 8      https://cdn.sofifa.net/players/208/333/23_60.png         Germany
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# 5      https://cdn.sofifa.net/flags/de.png       89         90
# 6      https://cdn.sofifa.net/flags/at.png       86         86
# 7      https://cdn.sofifa.net/flags/br.png       83         83
# 8      https://cdn.sofifa.net/flags/de.png       82         82
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# 5      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 6         Real Madrid CF     https://cdn.sofifa.net/teams/243/30.png  ...
# 7                Al Ahli  https://cdn.sofifa.net/teams/112387/30.png  ...
# 8      Borussia Dortmund      https://cdn.sofifa.net/teams/22/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real Face                     Position        Joined Loaned From  \
# 4           Yes  <span class="pos pos13">RCM   Sep 1, 2020         NaN
# 5           Yes   <span class="pos pos9">RDM   Jul 1, 2015         NaN
# 6           Yes   <span class="pos pos6">LCB   Jul 1, 2021         NaN
# 7           Yes  <span class="pos pos15">LCM  Jul 22, 2021         NaN
# 8           Yes  <span class="pos pos28">SUB  Feb 18, 2020         NaN
# ...         ...                          ...           ...         ...
# 17655        No  <span class="pos pos29">RES  Apr 11, 2022         NaN
# 17656        No  <span class="pos pos29">RES   Jan 1, 2022         NaN
# 17657        No  <span class="pos pos29">RES   Jun 6, 2021         NaN
# 17658        No  <span class="pos pos29">RES   Jan 1, 2020         NaN
# 17659        No  <span class="pos pos29">RES   Jan 8, 2020         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 4                      2026   172cm    68kg        €154.4M       23.0
# 5                      2025   177cm    75kg          €182M        6.0
# 6                      2026   180cm    78kg        €113.8M        4.0
# 7                      2024   183cm    80kg         €48.5M       15.0
# 8                      2024   186cm    86kg         €51.9M       23.0
# ...                     ...     ...     ...            ...        ...
# 17655                  2027   190cm    78kg          €218K       35.0
# 17656                  2026   195cm    84kg          €188K       21.0
# 17657                  2023   190cm    82kg          €142K       12.0
# 17658                  2021   187cm    79kg          €214K       40.0
# 17659                  2021   186cm    78kg          €131K       30.0
#
#       Best Overall Rating
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# ...                   ...
# 17655                 NaN
# 17656                 NaN
# 17657                 NaN
# 17658                 NaN
# 17659                 NaN
#
# [17656 rows x 29 columns]

# %%
df.drop(columns = ['Name', 'Age'])
## df.drop(['Name', 'Age'], axis = 1)
# Out:
#            ID                                             Photo  \
# 0      209658  https://cdn.sofifa.net/players/209/658/23_60.png
# 1      212198  https://cdn.sofifa.net/players/212/198/23_60.png
# 2      224334  https://cdn.sofifa.net/players/224/334/23_60.png
# 3      192985  https://cdn.sofifa.net/players/192/985/23_60.png
# 4      224232  https://cdn.sofifa.net/players/224/232/23_60.png
# ...       ...                                               ...
# 17655  269526  https://cdn.sofifa.net/players/269/526/23_60.png
# 17656  267946  https://cdn.sofifa.net/players/267/946/22_60.png
# 17657  270567  https://cdn.sofifa.net/players/270/567/23_60.png
# 17658  256624  https://cdn.sofifa.net/players/256/624/21_60.png
# 17659  256376  https://cdn.sofifa.net/players/256/376/21_60.png
#
#           Nationality                                 Flag  Overall  \
# 0             Germany  https://cdn.sofifa.net/flags/de.png       87
# 1            Portugal  https://cdn.sofifa.net/flags/pt.png       86
# 2           Argentina  https://cdn.sofifa.net/flags/ar.png       85
# 3             Belgium  https://cdn.sofifa.net/flags/be.png       91
# 4               Italy  https://cdn.sofifa.net/flags/it.png       86
# ...               ...                                  ...      ...
# 17655        China PR  https://cdn.sofifa.net/flags/cn.png       48
# 17656  Korea Republic  https://cdn.sofifa.net/flags/kr.png       48
# 17657          Turkey  https://cdn.sofifa.net/flags/tr.png       51
# 17658          Poland  https://cdn.sofifa.net/flags/pl.png       50
# 17659          Sweden  https://cdn.sofifa.net/flags/se.png       50
#
#        Potential               Club  \
# 0             88  FC Bayern München
# 1             87  Manchester United
# 2             85         Sevilla FC
# 3             91    Manchester City
# 4             89              Inter
# ...          ...                ...
# 17655         61      Meizhou Hakka
# 17656         64     Jeju United FC
# 17657         56       Ümraniyespor
# 17658         65     Fleetwood Town
# 17659         61     IFK Norrköping
#
#                                         Club Logo    Value   Wage  ...  \
# 0          https://cdn.sofifa.net/teams/21/30.png     €91M  €115K  ...
# 1          https://cdn.sofifa.net/teams/11/30.png   €78.5M  €190K  ...
# 2         https://cdn.sofifa.net/teams/481/30.png   €46.5M   €46K  ...
# 3          https://cdn.sofifa.net/teams/10/30.png  €107.5M  €350K  ...
# 4          https://cdn.sofifa.net/teams/44/30.png   €89.5M  €110K  ...
# ...                                           ...      ...    ...  ...
# 17655  https://cdn.sofifa.net/teams/114628/30.png    €100K   €500  ...
# 17656    https://cdn.sofifa.net/teams/1478/30.png    €100K   €500  ...
# 17657  https://cdn.sofifa.net/teams/113796/30.png     €70K    €2K  ...
# 17658  https://cdn.sofifa.net/teams/112260/30.png     €90K   €500  ...
# 17659     https://cdn.sofifa.net/teams/702/30.png     €90K   €500  ...
#
#        Real Face                     Position        Joined  Loaned From  \
# 0            Yes  <span class="pos pos28">SUB   Jul 1, 2018          NaN
# 1            Yes  <span class="pos pos15">LCM  Jan 30, 2020          NaN
# 2             No    <span class="pos pos7">LB  Sep 14, 2020          NaN
# 3            Yes  <span class="pos pos13">RCM  Aug 30, 2015          NaN
# 4            Yes  <span class="pos pos13">RCM   Sep 1, 2020          NaN
# ...          ...                          ...           ...          ...
# 17655         No  <span class="pos pos29">RES  Apr 11, 2022          NaN
# 17656         No  <span class="pos pos29">RES   Jan 1, 2022          NaN
# 17657         No  <span class="pos pos29">RES   Jun 6, 2021          NaN
# 17658         No  <span class="pos pos29">RES   Jan 1, 2020          NaN
# 17659         No  <span class="pos pos29">RES   Jan 8, 2020          NaN
#
#        Contract Valid Until Height Weight Release Clause Kit Number  \
# 0                      2026  189cm   82kg          €157M        8.0
# 1                      2026  179cm   69kg          €155M        8.0
# 2                      2024  172cm   69kg         €97.7M       19.0
# 3                      2025  181cm   70kg        €198.9M       17.0
# 4                      2026  172cm   68kg        €154.4M       23.0
# ...                     ...    ...    ...            ...        ...
# 17655                  2027  190cm   78kg          €218K       35.0
# 17656                  2026  195cm   84kg          €188K       21.0
# 17657                  2023  190cm   82kg          €142K       12.0
# 17658                  2021  187cm   79kg          €214K       40.0
# 17659                  2021  186cm   78kg          €131K       30.0
#
#       Best Overall Rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 17655                 NaN
# 17656                 NaN
# 17657                 NaN
# 17658                 NaN
# 17659                 NaN
#
# [17660 rows x 27 columns]

# %% [markdown]
# ### `#` G~H 에 대한 연습문제

# %% [markdown]
# `# 예제`: 결측치가 50퍼 이상인 열을 제외하라.

# %%
df.isna().mean()  ## := df.isna().sum() / len(df). Series
# Out:
# ID                          0.000000
# Name                        0.000000
# Age                         0.000000
# Photo                       0.000000
# Nationality                 0.000000
# Flag                        0.000000
# Overall                     0.000000
# Potential                   0.000000
# Club                        0.011948
# Club Logo                   0.000000
# Value                       0.000000
# Wage                        0.000000
# Special                     0.000000
# Preferred Foot              0.000000
# International Reputation    0.000000
# Weak Foot                   0.000000
# Skill Moves                 0.000000
# Work Rate                   0.000000
# Body Type                   0.002152
# Real Face                   0.002152
# Position                    0.001982
# Joined                      0.062174
# Loaned From                 0.960702
# Contract Valid Until        0.020442
# Height                      0.000000
# Weight                      0.000000
# Release Clause              0.065176
# Kit Number                  0.001982
# Best Overall Rating         0.998811
# dtype: float64

# %% [markdown]
# 풀이 1 : 무지성 직접 제외

# %%
df.drop(columns=['Loaned From','Best Overall Rating'])
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#             Work Rate         Body Type  Real Face  \
# 0        High/ Medium            Unique        Yes
# 1          High/ High            Unique        Yes
# 2          High/ High  Stocky (170-185)         No
# 3          High/ High            Unique        Yes
# 4          High/ High     Normal (170-)        Yes
# ...               ...               ...        ...
# 17655  Medium/ Medium     Normal (185+)         No
# 17656  Medium/ Medium       Lean (185+)         No
# 17657  Medium/ Medium       Lean (185+)         No
# 17658  Medium/ Medium     Normal (185+)         No
# 17659  Medium/ Medium     Normal (185+)         No
#
#                           Position        Joined  Contract Valid Until  \
# 0      <span class="pos pos28">SUB   Jul 1, 2018                  2026
# 1      <span class="pos pos15">LCM  Jan 30, 2020                  2026
# 2        <span class="pos pos7">LB  Sep 14, 2020                  2024
# 3      <span class="pos pos13">RCM  Aug 30, 2015                  2025
# 4      <span class="pos pos13">RCM   Sep 1, 2020                  2026
# ...                            ...           ...                   ...
# 17655  <span class="pos pos29">RES  Apr 11, 2022                  2027
# 17656  <span class="pos pos29">RES   Jan 1, 2022                  2026
# 17657  <span class="pos pos29">RES   Jun 6, 2021                  2023
# 17658  <span class="pos pos29">RES   Jan 1, 2020                  2021
# 17659  <span class="pos pos29">RES   Jan 8, 2020                  2021
#
#        Height Weight Release Clause Kit Number
# 0       189cm   82kg          €157M        8.0
# 1       179cm   69kg          €155M        8.0
# 2       172cm   69kg         €97.7M       19.0
# 3       181cm   70kg        €198.9M       17.0
# 4       172cm   68kg        €154.4M       23.0
# ...       ...    ...            ...        ...
# 17655   190cm   78kg          €218K       35.0
# 17656   195cm   84kg          €188K       21.0
# 17657   190cm   82kg          €142K       12.0
# 17658   187cm   79kg          €214K       40.0
# 17659   186cm   78kg          €131K       30.0
#
# [17660 rows x 27 columns]

# %% [markdown]
# 풀이 2 : 이성적인 풀이

# %%
df.loc[:, df.isna().mean() < 0.5]
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#             Work Rate         Body Type  Real Face  \
# 0        High/ Medium            Unique        Yes
# 1          High/ High            Unique        Yes
# 2          High/ High  Stocky (170-185)         No
# 3          High/ High            Unique        Yes
# 4          High/ High     Normal (170-)        Yes
# ...               ...               ...        ...
# 17655  Medium/ Medium     Normal (185+)         No
# 17656  Medium/ Medium       Lean (185+)         No
# 17657  Medium/ Medium       Lean (185+)         No
# 17658  Medium/ Medium     Normal (185+)         No
# 17659  Medium/ Medium     Normal (185+)         No
#
#                           Position        Joined  Contract Valid Until  \
# 0      <span class="pos pos28">SUB   Jul 1, 2018                  2026
# 1      <span class="pos pos15">LCM  Jan 30, 2020                  2026
# 2        <span class="pos pos7">LB  Sep 14, 2020                  2024
# 3      <span class="pos pos13">RCM  Aug 30, 2015                  2025
# 4      <span class="pos pos13">RCM   Sep 1, 2020                  2026
# ...                            ...           ...                   ...
# 17655  <span class="pos pos29">RES  Apr 11, 2022                  2027
# 17656  <span class="pos pos29">RES   Jan 1, 2022                  2026
# 17657  <span class="pos pos29">RES   Jun 6, 2021                  2023
# 17658  <span class="pos pos29">RES   Jan 1, 2020                  2021
# 17659  <span class="pos pos29">RES   Jan 8, 2020                  2021
#
#        Height Weight Release Clause Kit Number
# 0       189cm   82kg          €157M        8.0
# 1       179cm   69kg          €155M        8.0
# 2       172cm   69kg         €97.7M       19.0
# 3       181cm   70kg        €198.9M       17.0
# 4       172cm   68kg        €154.4M       23.0
# ...       ...    ...            ...        ...
# 17655   190cm   78kg          €218K       35.0
# 17656   195cm   84kg          €188K       21.0
# 17657   190cm   82kg          €142K       12.0
# 17658   187cm   79kg          €214K       40.0
# 17659   186cm   78kg          €131K       30.0
#
# [17660 rows x 27 columns]

# %% [markdown]
# ## 3. Pandas : missing

# %% [markdown]
# ### A. Numpy

# %%
np.nan
# Out:
# nan

# %%
arr = np.array([1,2,3,np.nan])
arr
# Out:
# array([ 1.,  2.,  3., nan])

# %%
arr.mean()
# Out:
# nan

# %%
print(type(np.nan))  ## np.nan 자체는 일종의 float로 취급된다.
print(type(arr[0]))
# Out:
# <class 'float'>
# <class 'numpy.float64'>

# %% [markdown]
# * 아래 두 개의 식은 거의 동일하다.

# %%
pd.Series([np.nan,1,2,3])
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# 3    3.0
# dtype: float64

# %%
pd.Series([pd.NA, 1, 2, 3])
# Out:
# 0    <NA>
# 1       1
# 2       2
# 3       3
# dtype: object

# %% [markdown]
# pd.Serise에 NaN 또는 <NA>가 있다면 연산할 때 제외함

# %%
pd.Series([np.nan,1,2,3]).mean()
# Out:
# 2.0

# %%
pd.Series([pd.NA,1,2,3]).mean()
# Out:
# 2.0

# %%
s1 = pd.Series([np.nan,1,2,3])
type(s1[0])
# Out:
# numpy.float64

# %%
s2 = pd.Series([pd.NA, 1,2,3])
type(s2[0])
# Out:
# pandas._libs.missing.NAType

# %% [markdown]
# > missing은 그냥 NaN이라고 보자.

# %% [markdown]
# \- 검출(★)

# %%
s1.isna()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
s2.isna()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
pd.isna(s1[0]), pd.isnull(s1[0])  ## 결측치가 있느냐?
# Out:
# (True, True)

# %%
pd.isna(s2[0]), pd.isnull(s2[0])  ## 결측치가 있느냐?
# Out:
# (True, True)

# %%
id(pd.isna), id(pd.isnull) # 같은함수
# Out:
# (135146401797248, 135146401797248)

# %% [markdown]
# > id를 찍었을 때 같다면 같은 함수이다.

# %% [markdown]
# ## 5. Pandas : query

# %%
ts = pd.DataFrame(np.random.normal(size=(20,4)),columns=list('ABCD'),index=pd.date_range('20221226',periods=20)).assign(E=['A']*10+['B']*10)
ts
# Out:
#                    A         B         C         D  E
# 2022-12-26  2.114531 -1.357376 -0.207229 -0.098154  A
# 2022-12-27  0.312752  0.627109 -0.551283  0.155706  A
# 2022-12-28 -1.087601  0.954356  0.014435  1.090911  A
# 2022-12-29  0.217482  1.161383 -0.071722 -0.323551  A
# 2022-12-30 -0.407107  0.294139 -2.176565  0.455862  A
# 2022-12-31 -0.281463 -0.119266  1.311237 -0.086091  A
# 2023-01-01  1.766233  0.861238  0.440594  0.115717  A
# 2023-01-02  1.244432 -0.203171 -0.882147 -0.555365  A
# 2023-01-03 -1.874380  0.661885 -1.495802 -0.928337  A
# 2023-01-04  2.201784 -0.118694 -1.180480 -1.323897  A
# 2023-01-05 -0.868834 -0.429863 -0.410214 -0.505256  B
# 2023-01-06  1.277424 -1.115292 -0.683880  1.286608  B
# 2023-01-07  1.300064  2.202771 -0.634653 -0.108274  B
# 2023-01-08  0.955565 -0.704828  0.620769 -1.776394  B
# 2023-01-09 -0.157803  1.336288  0.022712  0.347758  B
# 2023-01-10 -1.091290 -0.258790 -3.127253  0.181982  B
# 2023-01-11 -1.109814 -0.664264 -0.058458  2.748882  B
# 2023-01-12  0.501813 -0.339402  0.369923 -1.478936  B
# 2023-01-13 -1.042576 -1.388681 -0.679329 -2.863000  B
# 2023-01-14 -1.481058 -0.245890  0.057210 -0.000342  B

# %% [markdown]
# ### A. 기본 query

# %% [markdown]
# `-` 예시1: `A>0 and B<0`

# %%
ts.query('A>0 and B<0')
# Out:
#                    A         B         C         D  E
# 2022-12-26  2.114531 -1.357376 -0.207229 -0.098154  A
# 2023-01-02  1.244432 -0.203171 -0.882147 -0.555365  A
# 2023-01-04  2.201784 -0.118694 -1.180480 -1.323897  A
# 2023-01-06  1.277424 -1.115292 -0.683880  1.286608  B
# 2023-01-08  0.955565 -0.704828  0.620769 -1.776394  B
# 2023-01-12  0.501813 -0.339402  0.369923 -1.478936  B

# %% [markdown]
# `-` 예시2: `A<B<C`

# %%
ts.query('A<B<C')
# Out:
#                    A         B         C         D  E
# 2022-12-31 -0.281463 -0.119266  1.311237 -0.086091  A
# 2023-01-05 -0.868834 -0.429863 -0.410214 -0.505256  B
# 2023-01-11 -1.109814 -0.664264 -0.058458  2.748882  B
# 2023-01-14 -1.481058 -0.245890  0.057210 -0.000342  B

# %% [markdown]
# `-` 예시3: `(A+B/2) > 0`

# %%
ts.query('(A+B)/2 > 0')
# Out:
#                    A         B         C         D  E
# 2022-12-26  2.114531 -1.357376 -0.207229 -0.098154  A
# 2022-12-27  0.312752  0.627109 -0.551283  0.155706  A
# 2022-12-29  0.217482  1.161383 -0.071722 -0.323551  A
# 2023-01-01  1.766233  0.861238  0.440594  0.115717  A
# 2023-01-02  1.244432 -0.203171 -0.882147 -0.555365  A
# 2023-01-04  2.201784 -0.118694 -1.180480 -1.323897  A
# 2023-01-06  1.277424 -1.115292 -0.683880  1.286608  B
# 2023-01-07  1.300064  2.202771 -0.634653 -0.108274  B
# 2023-01-08  0.955565 -0.704828  0.620769 -1.776394  B
# 2023-01-09 -0.157803  1.336288  0.022712  0.347758  B
# 2023-01-12  0.501813 -0.339402  0.369923 -1.478936  B

# %% [markdown]
# `-` 예시4: `(A+B/2) > 0` and `E=='A'`

# %%
ts.query('(A+B)/2 > 0 and E == "A"')   ## string 조건을 넣어주고 싶으면 다른 따옴표로 구분하면 된다.
# Out:
#                    A         B         C         D  E
# 2022-12-26  2.114531 -1.357376 -0.207229 -0.098154  A
# 2022-12-27  0.312752  0.627109 -0.551283  0.155706  A
# 2022-12-29  0.217482  1.161383 -0.071722 -0.323551  A
# 2023-01-01  1.766233  0.861238  0.440594  0.115717  A
# 2023-01-02  1.244432 -0.203171 -0.882147 -0.555365  A
# 2023-01-04  2.201784 -0.118694 -1.180480 -1.323897  A

# %% [markdown]
# ### B. 외부변수를 이용

# %% [markdown]
# `-` 예시1: `A > mean(A)`

# %%
mean = ts.A.mean()
mean
# Out:
# 0.12450772273787492

# %%
#ts.query('A > np.mean(A)')   ## 이건 안됨
#ts.query('A > A.mean()')      ## 이건 되긴 함

#ts.query('A > mean')    ## column 중 하나인지 뭔지 헷갈림, 그래서 안됨

ts.query('A > @mean')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-91cd1dfcb28b> in <cell line: 6>()
#       4 #ts.query('A > mean')    ## column 중 하나인지 뭔지 헷갈림, 그래서 안됨
#       5
# ----> 6 ts.query('A > @mean')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4472         kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473         kwargs["target"] = None
# -> 4474         res = self.eval(expr, **kwargs)
#    4475
#    4476         try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4610         kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
#    4611
# -> 4612         return _eval(expr, inplace=inplace, **kwargs)
#    4613
#    4614     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     356         eng = ENGINES[engine]
#     357         eng_inst = eng(parsed_expr)
# --> 358         ret = eng_inst.evaluate()
#     359
#     360         if parsed_expr.assigner is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/engines.py in evaluate(self)
#      79
#      80         # make sure no names in resolvers and locals/globals clash
# ---> 81         res = self._evaluate()
#      82         return reconstruct_object(
#      83             self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/engines.py in _evaluate(self)
#     120         scope = env.full_scope
#     121         _check_ne_builtin_clash(self.expr)
# --> 122         return ne.evaluate(s, local_dict=scope)
#     123
#     124
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in evaluate(ex, local_dict, global_dict, out, order, casting, _frame_depth, **kwargs)
#     941         return re_evaluate(local_dict=local_dict, _frame_depth=_frame_depth)
#     942     else:
# --> 943         raise e
#     944
#     945 def re_evaluate(local_dict: Optional[Dict] = None,
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in validate(ex, local_dict, global_dict, out, order, casting, _frame_depth, **kwargs)
#     849         expr_key = (ex, tuple(sorted(context.items())))
#     850         if expr_key not in _names_cache:
# --> 851             _names_cache[expr_key] = getExprNames(ex, context)
#     852         names, ex_uses_vml = _names_cache[expr_key]
#     853         arguments = getArguments(names, local_dict, global_dict, _frame_depth=_frame_depth)
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in getExprNames(text, context)
#     712
#     713 def getExprNames(text, context):
# --> 714     ex = stringToExpression(text, {}, context)
#     715     ast = expressionToAST(ex)
#     716     input_order = getInputOrder(ast, None)
#
# /usr/local/lib/python3.10/dist-packages/numexpr/necompiler.py in stringToExpression(s, types, context)
#     272     no_whitespace = re.sub(r'\s+', '', s)
#     273     if _forbidden_re.search(no_whitespace) is not None:
# --> 274         raise ValueError(f'Expression {s} has forbidden control characters.')
#     275
#     276     old_ctx = expressions._context.get_current_context()
#
# ValueError: Expression (A) > (__pd_eval_local_mean) has forbidden control characters.

# %% [markdown]
# ### C. Index로 query

# %% [markdown]
# `-` 예시: (2022년 12월30일 보다 이전 날짜) $\cup$ (2023년 1월10일)

# %%
ts
# Out:
#                    A         B         C         D  E
# 2022-12-26  2.114531 -1.357376 -0.207229 -0.098154  A
# 2022-12-27  0.312752  0.627109 -0.551283  0.155706  A
# 2022-12-28 -1.087601  0.954356  0.014435  1.090911  A
# 2022-12-29  0.217482  1.161383 -0.071722 -0.323551  A
# 2022-12-30 -0.407107  0.294139 -2.176565  0.455862  A
# 2022-12-31 -0.281463 -0.119266  1.311237 -0.086091  A
# 2023-01-01  1.766233  0.861238  0.440594  0.115717  A
# 2023-01-02  1.244432 -0.203171 -0.882147 -0.555365  A
# 2023-01-03 -1.874380  0.661885 -1.495802 -0.928337  A
# 2023-01-04  2.201784 -0.118694 -1.180480 -1.323897  A
# 2023-01-05 -0.868834 -0.429863 -0.410214 -0.505256  B
# 2023-01-06  1.277424 -1.115292 -0.683880  1.286608  B
# 2023-01-07  1.300064  2.202771 -0.634653 -0.108274  B
# 2023-01-08  0.955565 -0.704828  0.620769 -1.776394  B
# 2023-01-09 -0.157803  1.336288  0.022712  0.347758  B
# 2023-01-10 -1.091290 -0.258790 -3.127253  0.181982  B
# 2023-01-11 -1.109814 -0.664264 -0.058458  2.748882  B
# 2023-01-12  0.501813 -0.339402  0.369923 -1.478936  B
# 2023-01-13 -1.042576 -1.388681 -0.679329 -2.863000  B
# 2023-01-14 -1.481058 -0.245890  0.057210 -0.000342  B

# %%
ts.query('index <= "2022-12-30" or index == "2023-01-10"')
# Out:
#                    A         B         C         D  E
# 2022-12-26  2.114531 -1.357376 -0.207229 -0.098154  A
# 2022-12-27  0.312752  0.627109 -0.551283  0.155706  A
# 2022-12-28 -1.087601  0.954356  0.014435  1.090911  A
# 2022-12-29  0.217482  1.161383 -0.071722 -0.323551  A
# 2022-12-30 -0.407107  0.294139 -2.176565  0.455862  A
# 2023-01-10 -1.091290 -0.258790 -3.127253  0.181982  B

# %% [markdown]
# ### D. 열의 이름에 공백이 있을 경우

# %% [markdown]
# 열의 이름에 공백이 있으면 백틱을 이용하면 된다.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/FIFA23_official_data.csv')
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Joined', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause', 'Kit Number', 'Best Overall Rating'],
#       dtype='object')

# %%
df.query('`Skill Moves` > 4')
# Out:
#            ID           Name  Age  \
# 19     193082    J. Cuadrado   34
# 27     189509         Thiago   31
# 44     232411      C. Nkunku   24
# 62     233927  Lucas Paquetá   24
# 75     231747      K. Mbappé   23
# ...       ...            ...  ...
# 4516   253755   Talles Magno   20
# 4643   246548    O. Sahraoui   21
# 4872   251570      R. Cherki   18
# 5361   225712  D. Bahamboula   27
# 10452  212455  17 H. Mastour   18
#
#                                                   Photo Nationality  \
# 19     https://cdn.sofifa.net/players/193/082/23_60.png    Colombia
# 27     https://cdn.sofifa.net/players/189/509/23_60.png       Spain
# 44     https://cdn.sofifa.net/players/232/411/23_60.png      France
# 62     https://cdn.sofifa.net/players/233/927/23_60.png      Brazil
# 75     https://cdn.sofifa.net/players/231/747/23_60.png      France
# ...                                                 ...         ...
# 4516   https://cdn.sofifa.net/players/253/755/23_60.png      Brazil
# 4643   https://cdn.sofifa.net/players/246/548/23_60.png      Norway
# 4872   https://cdn.sofifa.net/players/251/570/23_60.png      France
# 5361   https://cdn.sofifa.net/players/225/712/23_60.png       Congo
# 10452  https://cdn.sofifa.net/players/212/455/17_60.png     Morocco
#
#                                       Flag  Overall  Potential  \
# 19     https://cdn.sofifa.net/flags/co.png       83         83
# 27     https://cdn.sofifa.net/flags/es.png       86         86
# 44     https://cdn.sofifa.net/flags/fr.png       86         89
# 62     https://cdn.sofifa.net/flags/br.png       82         87
# 75     https://cdn.sofifa.net/flags/fr.png       91         95
# ...                                    ...      ...        ...
# 4516   https://cdn.sofifa.net/flags/br.png       71         83
# 4643   https://cdn.sofifa.net/flags/no.png       67         78
# 4872   https://cdn.sofifa.net/flags/fr.png       73         88
# 5361   https://cdn.sofifa.net/flags/cg.png       63         63
# 10452  https://cdn.sofifa.net/flags/ma.png       65         76
#
#                       Club                                   Club Logo  ...  \
# 19                Juventus      https://cdn.sofifa.net/teams/45/30.png  ...
# 27               Liverpool       https://cdn.sofifa.net/teams/9/30.png  ...
# 44              RB Leipzig  https://cdn.sofifa.net/teams/112172/30.png  ...
# 62      Olympique Lyonnais      https://cdn.sofifa.net/teams/66/30.png  ...
# 75     Paris Saint-Germain      https://cdn.sofifa.net/teams/73/30.png  ...
# ...                    ...                                         ...  ...
# 4516      New York City FC  https://cdn.sofifa.net/teams/112828/30.png  ...
# 4643     Vålerenga Fotball     https://cdn.sofifa.net/teams/920/30.png  ...
# 4872    Olympique Lyonnais      https://cdn.sofifa.net/teams/66/30.png  ...
# 5361         Livingston FC     https://cdn.sofifa.net/teams/621/30.png  ...
# 10452           PEC Zwolle    https://cdn.sofifa.net/teams/1914/30.png  ...
#
#       Real Face                     Position        Joined  \
# 19          Yes    <span class="pos pos3">RB   Jul 1, 2017
# 27          Yes  <span class="pos pos15">LCM  Sep 18, 2020
# 44          Yes  <span class="pos pos28">SUB           NaN
# 62          Yes  <span class="pos pos15">LCM   Oct 1, 2020
# 75          Yes   <span class="pos pos25">ST   Jul 1, 2018
# ...         ...                          ...           ...
# 4516         No   <span class="pos pos16">LM  May 18, 2021
# 4643         No   <span class="pos pos27">LW  May 15, 2019
# 4872         No  <span class="pos pos28">SUB   Jul 7, 2019
# 5361         No  <span class="pos pos28">SUB   Jul 9, 2022
# 10452        No  <span class="pos pos28">SUB           NaN
#
#                                      Loaned From  Contract Valid Until  \
# 19                                           NaN                  2023
# 27                                           NaN                  2024
# 44                                           NaN                   NaN
# 62                                           NaN                  2025
# 75                                           NaN                  2025
# ...                                          ...                   ...
# 4516                                         NaN                  2026
# 4643                                         NaN                  2023
# 4872                                         NaN                  2023
# 5361                                         NaN                  2024
# 10452  <a href="/team/47/ac-milan/">AC Milan</a>          Jun 30, 2017
#
#        Height  Weight Release Clause Kit Number Best Overall Rating
# 19      179cm    72kg           €23M       11.0                 NaN
# 27      174cm    70kg        €102.7M        6.0                 NaN
# 44      175cm    73kg        €166.9M       12.0                 NaN
# 62      180cm    72kg         €90.9M       10.0                 NaN
# 75      182cm    73kg        €366.7M        7.0                 NaN
# ...       ...     ...            ...        ...                 ...
# 4516    186cm    70kg          €7.7M       43.0                 NaN
# 4643    170cm    65kg          €3.3M       10.0                 NaN
# 4872    176cm    71kg         €17.7M       18.0                 NaN
# 5361    185cm    70kg          €875K        7.0                 NaN
# 10452   175cm    63kg            NaN       98.0                 NaN
#
# [65 rows x 29 columns]

# %% [markdown]
# ## 5. Pandas : 할당

# %%
np.random.seed(43052)
att = np.random.choice(np.arange(10,21)*5,20)
rep = np.random.choice(np.arange(5,21)*5,20)
mid = np.random.choice(np.arange(0,21)*5,20)
fin = np.random.choice(np.arange(0,21)*5,20)
df = pd.DataFrame({'att':att,'rep':rep,'mid':mid,'fin':fin})
df
# Out:
#     att  rep  mid  fin
# 0    65   55   50   40
# 1    95  100   50   80
# 2    65   90   60   30
# 3    55   80   75   80
# 4    80   30   30  100
# 5    75   40  100   15
# 6    65   45   45   90
# 7    60   60   25    0
# 8    95   65   20   10
# 9    90   80   80   20
# 10   55   75   35   25
# 11   95   95   45    0
# 12   95   55   15   35
# 13   50   80   40   30
# 14   50   55   15   85
# 15   95   30   30   95
# 16   50   50   45   10
# 17   65   55   15   45
# 18   70   70   40   35
# 19   90   90   80   90

# %% [markdown]
# ### A. ```df.assign()```

# %% [markdown]
# `-` 예시: `total = att*0.1 + rep*0.2 + mid*0.35 + fin*0.35` 를 계산하여 할당

# %%
df_total = df.assign(total = df.att*0.1 + df.rep*0.2 + df.mid*0.35 + df.fin*0.35)   ## 일시적 변화임
df_total
# Out:
#     att  rep  mid  fin  total
# 0    65   55   50   40  49.00
# 1    95  100   50   80  75.00
# 2    65   90   60   30  56.00
# 3    55   80   75   80  75.75
# 4    80   30   30  100  59.50
# 5    75   40  100   15  55.75
# 6    65   45   45   90  62.75
# 7    60   60   25    0  26.75
# 8    95   65   20   10  33.00
# 9    90   80   80   20  60.00
# 10   55   75   35   25  41.50
# 11   95   95   45    0  44.25
# 12   95   55   15   35  38.00
# 13   50   80   40   30  45.50
# 14   50   55   15   85  51.00
# 15   95   30   30   95  59.25
# 16   50   50   45   10  34.25
# 17   65   55   15   45  38.50
# 18   70   70   40   35  47.25
# 19   90   90   80   90  86.50

# %% [markdown]
# ### B. ```df.eval()```

# %%
df.eval('total = att*0.1 + rep*0.2 + mid*0.3 + fin*0.4')    ## query를 쓰는 것처럼, 원본 데이터를 변화시키지 않음
# Out:
#     att  rep  mid  fin  total
# 0    65   55   50   40   48.5
# 1    95  100   50   80   76.5
# 2    65   90   60   30   54.5
# 3    55   80   75   80   76.0
# 4    80   30   30  100   63.0
# 5    75   40  100   15   51.5
# 6    65   45   45   90   65.0
# 7    60   60   25    0   25.5
# 8    95   65   20   10   32.5
# 9    90   80   80   20   57.0
# 10   55   75   35   25   41.0
# 11   95   95   45    0   42.0
# 12   95   55   15   35   39.0
# 13   50   80   40   30   45.0
# 14   50   55   15   85   54.5
# 15   95   30   30   95   62.5
# 16   50   50   45   10   32.5
# 17   65   55   15   45   40.0
# 18   70   70   40   35   47.0
# 19   90   90   80   90   87.0

# %% [markdown]
# > but, 사칙연산과 같은 기초연산 수준에서만 잘 작동한다.

# %% [markdown]
# ### C. ```df[colname] = xxx```
#
# > 별로 안쓰는 방법

# %%
df['total'] = df.att*0.1 + df.rep*0.2 + df.mid*0.3 + df.fin*0.4   ## 원래의 데이터프레임을 손상시킨다.
df
# Out:
#     att  rep  mid  fin  total
# 0    65   55   50   40   48.5
# 1    95  100   50   80   76.5
# 2    65   90   60   30   54.5
# 3    55   80   75   80   76.0
# 4    80   30   30  100   63.0
# 5    75   40  100   15   51.5
# 6    65   45   45   90   65.0
# 7    60   60   25    0   25.5
# 8    95   65   20   10   32.5
# 9    90   80   80   20   57.0
# 10   55   75   35   25   41.0
# 11   95   95   45    0   42.0
# 12   95   55   15   35   39.0
# 13   50   80   40   30   45.0
# 14   50   55   15   85   54.5
# 15   95   30   30   95   62.5
# 16   50   50   45   10   32.5
# 17   65   55   15   45   40.0
# 18   70   70   40   35   47.0
# 19   90   90   80   90   87.0

# %% [markdown]
# ## 6. Pandas : transform column(★★)

# %% [markdown]
# ### ```lambda```

# %% [markdown]
# `-` 예시1: $x \to x+2$

# %%
"""
def f(x) :
  return x + 2

해당 코드와 동일하다.
"""

f = lambda x: x+2
print(f(3))

print((lambda x : x+2)(3))    ## (lambda x : x+2) 자체가 함수이므로, 뒤에 변수만 지정해주면 된다.
# Out:
# 5
# 5

# %% [markdown]
# `-` 예시2: $x,y \to x+y$

# %%
(lambda x,y : x+y)(1,3)
# Out:
# 4

# %% [markdown]
# `-` 예시3: '2023-09' $\to$ 9  (format : int)

# %%
(lambda x : int(x[-2:]))('2023-09')   ## -1번째(뒤에서 두번째 원소까지 추출)
# Out:
# 9

# %% [markdown]
# `-` 예시4: '2023-09' $\to$ (2023, 9) (format : tuple)

# %%
(lambda x : (int(x[:4]), int(x[-2:])))('2023-09')
# Out:
# (2023, 9)

# %% [markdown]
# `-` 예시5: 문자열이 'cat'이면 1 'dog' 이면 0 // 'cat이면 1 'cat'이 아니면 0

# %%
(lambda x : 1 if x == 'cat' else 0)('cat')
## (lambda x : pd.Series(x == 'cat').sum())('cat') ## 이것도 된다.
# Out:
# 1

# %% [markdown]
# ### B. `map`
#
# > 함수의 output들을 엮는다. 매핑하는 거

# %% [markdown]
# :`-` 개념: `map(f,[x1,x2,...xn])=[f(x1),f(x2),...,f(xn)]`

# %% [markdown]
# `-` 예시1: `x->x+1`을 `[1,2,3]`에 적용

# %%
f = lambda x: x+1
list(map(f,[1,2,3]))
# Out:
# [2, 3, 4]

# %%
list(map(lambda x : x + 1, [1,2,3]))
# Out:
# [2, 3, 4]

# %% [markdown]
# `-` 예시2 `df.Height`열 변환하기 (xxxcm 라고 적혀있는 것을 cm 없애고 키만 뽑기)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/FIFA23_official_data.csv')
s = df.Height[:5]
s
# Out:
# 0    189cm
# 1    179cm
# 2    172cm
# 3    181cm
# 4    172cm
# Name: Height, dtype: object

# %%
s.replace('cm', '')
# Out:
# 0    189cm
# 1    179cm
# 2    172cm
# 3    181cm
# 4    172cm
# Name: Height, dtype: object

# %%
df.assign(height = [])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-207-9b41a9a2518b> in <cell line: 1>()
# ----> 1 df.assign(height = [])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in assign(self, **kwargs)
#    4887
#    4888         for k, v in kwargs.items():
# -> 4889             data[k] = com.apply_if_callable(v, data)
#    4890         return data
#    4891
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# -> 4915             com.require_length_match(value, self.index)
#    4916         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4917
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     569     """
#     570     if len(data) != len(index):
# --> 571         raise ValueError(
#     572             "Length of values "
#     573             f"({len(data)}) "
#
# ValueError: Length of values (0) does not match length of index (17660)

# %%
list(map(lambda x : int(x[:-2]), s))
# Out:
# [189, 179, 172, 181, 172]

# %%
df.assign(Height = list(map(lambda x: int(x.replace('cm','')), df.Height)))
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real Face                     Position        Joined Loaned From  \
# 0           Yes  <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1           Yes  <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2            No    <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3           Yes  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4           Yes  <span class="pos pos13">RCM   Sep 1, 2020         NaN
# ...         ...                          ...           ...         ...
# 17655        No  <span class="pos pos29">RES  Apr 11, 2022         NaN
# 17656        No  <span class="pos pos29">RES   Jan 1, 2022         NaN
# 17657        No  <span class="pos pos29">RES   Jun 6, 2021         NaN
# 17658        No  <span class="pos pos29">RES   Jan 1, 2020         NaN
# 17659        No  <span class="pos pos29">RES   Jan 8, 2020         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 0                      2026     189    82kg          €157M        8.0
# 1                      2026     179    69kg          €155M        8.0
# 2                      2024     172    69kg         €97.7M       19.0
# 3                      2025     181    70kg        €198.9M       17.0
# 4                      2026     172    68kg        €154.4M       23.0
# ...                     ...     ...     ...            ...        ...
# 17655                  2027     190    78kg          €218K       35.0
# 17656                  2026     195    84kg          €188K       21.0
# 17657                  2023     190    82kg          €142K       12.0
# 17658                  2021     187    79kg          €214K       40.0
# 17659                  2021     186    78kg          €131K       30.0
#
#       Best Overall Rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 17655                 NaN
# 17656                 NaN
# 17657                 NaN
# 17658                 NaN
# 17659                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# 사실 수틀리면 컴프리헨션 쓰면 된다.

# %%
df.assign(Height = [int(s.replace('cm', '')) for s in df.Height])
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real Face                     Position        Joined Loaned From  \
# 0           Yes  <span class="pos pos28">SUB   Jul 1, 2018         NaN
# 1           Yes  <span class="pos pos15">LCM  Jan 30, 2020         NaN
# 2            No    <span class="pos pos7">LB  Sep 14, 2020         NaN
# 3           Yes  <span class="pos pos13">RCM  Aug 30, 2015         NaN
# 4           Yes  <span class="pos pos13">RCM   Sep 1, 2020         NaN
# ...         ...                          ...           ...         ...
# 17655        No  <span class="pos pos29">RES  Apr 11, 2022         NaN
# 17656        No  <span class="pos pos29">RES   Jan 1, 2022         NaN
# 17657        No  <span class="pos pos29">RES   Jun 6, 2021         NaN
# 17658        No  <span class="pos pos29">RES   Jan 1, 2020         NaN
# 17659        No  <span class="pos pos29">RES   Jan 8, 2020         NaN
#
#        Contract Valid Until  Height  Weight Release Clause Kit Number  \
# 0                      2026     189    82kg          €157M        8.0
# 1                      2026     179    69kg          €155M        8.0
# 2                      2024     172    69kg         €97.7M       19.0
# 3                      2025     181    70kg        €198.9M       17.0
# 4                      2026     172    68kg        €154.4M       23.0
# ...                     ...     ...     ...            ...        ...
# 17655                  2027     190    78kg          €218K       35.0
# 17656                  2026     195    84kg          €188K       21.0
# 17657                  2023     190    82kg          €142K       12.0
# 17658                  2021     187    79kg          €214K       40.0
# 17659                  2021     186    78kg          €131K       30.0
#
#       Best Overall Rating
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 17655                 NaN
# 17656                 NaN
# 17657                 NaN
# 17658                 NaN
# 17659                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# `# 예시4` -- `df.Position` 열에 아래와 같은 변환을 수행하고, 변환된 열을 할당하라.

# %% [markdown]
# |before|after|
# |:-:|:-:|
# |`<span class="pos pos28">SUB`|`SUB`|
# |`<span class="pos pos15">LCM`|`LCM`|
# |`<span class="pos pos7">LB`|`LB`|
# |`<span class="pos pos13">RCM`|`RCM`|
# |`<span class="pos pos13">RCM`|`RCM`|

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/posts/FIFA23_official_data.csv')

# %%
x = df.Position[0]
x
# Out:
# '<span class="pos pos28">SUB'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17660 entries, 0 to 17659
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        17660 non-null  int64
#  1   Name                      17660 non-null  object
#  2   Age                       17660 non-null  int64
#  3   Photo                     17660 non-null  object
#  4   Nationality               17660 non-null  object
#  5   Flag                      17660 non-null  object
#  6   Overall                   17660 non-null  int64
#  7   Potential                 17660 non-null  int64
#  8   Club                      17449 non-null  object
#  9   Club Logo                 17660 non-null  object
#  10  Value                     17660 non-null  object
#  11  Wage                      17660 non-null  object
#  12  Special                   17660 non-null  int64
#  13  Preferred Foot            17660 non-null  object
#  14  International Reputation  17660 non-null  float64
#  15  Weak Foot                 17660 non-null  float64
#  16  Skill Moves               17660 non-null  float64
#  17  Work Rate                 17660 non-null  object
#  18  Body Type                 17622 non-null  object
#  19  Real Face                 17622 non-null  object
#  20  Position                  17625 non-null  object
#  21  Joined                    16562 non-null  object
#  22  Loaned From               694 non-null    object
#  23  Contract Valid Until      17299 non-null  object
#  24  Height                    17660 non-null  object
#  25  Weight                    17660 non-null  object
#  26  Release Clause            16509 non-null  object
#  27  Kit Number                17625 non-null  float64
#  28  Best Overall Rating       21 non-null     object
# dtypes: float64(4), int64(5), object(20)
# memory usage: 3.9+ MB

# %%
df.Position.isna().sum()
# Out:
# 35

# %%
df.assign(Position = list(map(lambda x : x.split(">")[-1] if not pd.isna(x) else 'NA', df.Position)))
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real Face Position        Joined Loaned From  Contract Valid Until  \
# 0           Yes      SUB   Jul 1, 2018         NaN                  2026
# 1           Yes      LCM  Jan 30, 2020         NaN                  2026
# 2            No       LB  Sep 14, 2020         NaN                  2024
# 3           Yes      RCM  Aug 30, 2015         NaN                  2025
# 4           Yes      RCM   Sep 1, 2020         NaN                  2026
# ...         ...      ...           ...         ...                   ...
# 17655        No      RES  Apr 11, 2022         NaN                  2027
# 17656        No      RES   Jan 1, 2022         NaN                  2026
# 17657        No      RES   Jun 6, 2021         NaN                  2023
# 17658        No      RES   Jan 1, 2020         NaN                  2021
# 17659        No      RES   Jan 8, 2020         NaN                  2021
#
#        Height  Weight Release Clause Kit Number Best Overall Rating
# 0       189cm    82kg          €157M        8.0                 NaN
# 1       179cm    69kg          €155M        8.0                 NaN
# 2       172cm    69kg         €97.7M       19.0                 NaN
# 3       181cm    70kg        €198.9M       17.0                 NaN
# 4       172cm    68kg        €154.4M       23.0                 NaN
# ...       ...     ...            ...        ...                 ...
# 17655   190cm    78kg          €218K       35.0                 NaN
# 17656   195cm    84kg          €188K       21.0                 NaN
# 17657   190cm    82kg          €142K       12.0                 NaN
# 17658   187cm    79kg          €214K       40.0                 NaN
# 17659   186cm    78kg          €131K       30.0                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# `-` (풀이2) -- 리스트컴프리헨션

# %%
f = lambda x: x.split(">")[-1] if not pd.isna(x) else 'None'

# %%
df.assign(Position = [f(s) for s in df.Position])
# Out:
#            ID             Name  Age  \
# 0      209658      L. Goretzka   27
# 1      212198  Bruno Fernandes   27
# 2      224334         M. Acuña   30
# 3      192985     K. De Bruyne   31
# 4      224232       N. Barella   25
# ...       ...              ...  ...
# 17655  269526    Deng Xiongtao   19
# 17656  267946   22 Lim Jun Sub   17
# 17657  270567         A. Demir   25
# 17658  256624     21 S. Czajor   18
# 17659  256376  21 F. Jakobsson   20
#
#                                                   Photo     Nationality  \
# 0      https://cdn.sofifa.net/players/209/658/23_60.png         Germany
# 1      https://cdn.sofifa.net/players/212/198/23_60.png        Portugal
# 2      https://cdn.sofifa.net/players/224/334/23_60.png       Argentina
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# 4      https://cdn.sofifa.net/players/224/232/23_60.png           Italy
# ...                                                 ...             ...
# 17655  https://cdn.sofifa.net/players/269/526/23_60.png        China PR
# 17656  https://cdn.sofifa.net/players/267/946/22_60.png  Korea Republic
# 17657  https://cdn.sofifa.net/players/270/567/23_60.png          Turkey
# 17658  https://cdn.sofifa.net/players/256/624/21_60.png          Poland
# 17659  https://cdn.sofifa.net/players/256/376/21_60.png          Sweden
#
#                                       Flag  Overall  Potential  \
# 0      https://cdn.sofifa.net/flags/de.png       87         88
# 1      https://cdn.sofifa.net/flags/pt.png       86         87
# 2      https://cdn.sofifa.net/flags/ar.png       85         85
# 3      https://cdn.sofifa.net/flags/be.png       91         91
# 4      https://cdn.sofifa.net/flags/it.png       86         89
# ...                                    ...      ...        ...
# 17655  https://cdn.sofifa.net/flags/cn.png       48         61
# 17656  https://cdn.sofifa.net/flags/kr.png       48         64
# 17657  https://cdn.sofifa.net/flags/tr.png       51         56
# 17658  https://cdn.sofifa.net/flags/pl.png       50         65
# 17659  https://cdn.sofifa.net/flags/se.png       50         61
#
#                     Club                                   Club Logo  ...  \
# 0      FC Bayern München      https://cdn.sofifa.net/teams/21/30.png  ...
# 1      Manchester United      https://cdn.sofifa.net/teams/11/30.png  ...
# 2             Sevilla FC     https://cdn.sofifa.net/teams/481/30.png  ...
# 3        Manchester City      https://cdn.sofifa.net/teams/10/30.png  ...
# 4                  Inter      https://cdn.sofifa.net/teams/44/30.png  ...
# ...                  ...                                         ...  ...
# 17655      Meizhou Hakka  https://cdn.sofifa.net/teams/114628/30.png  ...
# 17656     Jeju United FC    https://cdn.sofifa.net/teams/1478/30.png  ...
# 17657       Ümraniyespor  https://cdn.sofifa.net/teams/113796/30.png  ...
# 17658     Fleetwood Town  https://cdn.sofifa.net/teams/112260/30.png  ...
# 17659     IFK Norrköping     https://cdn.sofifa.net/teams/702/30.png  ...
#
#       Real Face Position        Joined Loaned From  Contract Valid Until  \
# 0           Yes      SUB   Jul 1, 2018         NaN                  2026
# 1           Yes      LCM  Jan 30, 2020         NaN                  2026
# 2            No       LB  Sep 14, 2020         NaN                  2024
# 3           Yes      RCM  Aug 30, 2015         NaN                  2025
# 4           Yes      RCM   Sep 1, 2020         NaN                  2026
# ...         ...      ...           ...         ...                   ...
# 17655        No      RES  Apr 11, 2022         NaN                  2027
# 17656        No      RES   Jan 1, 2022         NaN                  2026
# 17657        No      RES   Jun 6, 2021         NaN                  2023
# 17658        No      RES   Jan 1, 2020         NaN                  2021
# 17659        No      RES   Jan 8, 2020         NaN                  2021
#
#        Height  Weight Release Clause Kit Number Best Overall Rating
# 0       189cm    82kg          €157M        8.0                 NaN
# 1       179cm    69kg          €155M        8.0                 NaN
# 2       172cm    69kg         €97.7M       19.0                 NaN
# 3       181cm    70kg        €198.9M       17.0                 NaN
# 4       172cm    68kg        €154.4M       23.0                 NaN
# ...       ...     ...            ...        ...                 ...
# 17655   190cm    78kg          €218K       35.0                 NaN
# 17656   195cm    84kg          €188K       21.0                 NaN
# 17657   190cm    82kg          €142K       12.0                 NaN
# 17658   187cm    79kg          €214K       40.0                 NaN
# 17659   186cm    78kg          €131K       30.0                 NaN
#
# [17660 rows x 29 columns]

# %% [markdown]
# > mapping하는 게 조금 더 자연스럽고 한번에 쓸 수 있다.
