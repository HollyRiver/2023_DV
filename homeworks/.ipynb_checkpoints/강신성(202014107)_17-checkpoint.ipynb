# %% [markdown]
# ### 사전작업

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import json
import requests

# %%
#import plotly.io as pio
#pio.renderers.default = "notebook_connected"

# %% [markdown]
# **데이터 불러오기**

# %%
global_dict = json.loads(requests.get('https://raw.githubusercontent.com/southkorea/southkorea-maps/master/kostat/2018/json/skorea-provinces-2018-geo.json').text)
local_dict = json.loads(requests.get('https://raw.githubusercontent.com/southkorea/southkorea-maps/master/kostat/2018/json/skorea-municipalities-2018-geo.json').text)
#--#
url = 'https://raw.githubusercontent.com/guebin/DV2022/main/posts/Energy/{}.csv'
prov = ['Seoul', 'Busan', 'Daegu', 'Incheon', 
        'Gwangju', 'Daejeon', 'Ulsan', 'Sejongsi', 
        'Gyeonggi-do', 'Gangwon-do', 'Chungcheongbuk-do', 
        'Chungcheongnam-do', 'Jeollabuk-do', 'Jeollanam-do', 
        'Gyeongsangbuk-do', 'Gyeongsangnam-do', 'Jeju-do']
df = pd.concat([pd.read_csv(url.format(p+y)).assign(년도=y, 시도=p) for p in prov for y in ['2018', '2019', '2020', '2021']]).reset_index(drop=True)\
.assign(년도 = lambda df: df.년도.astype(int))\
.set_index(['년도','시도','지역']).applymap(lambda x: int(str(x).replace(',','')))\
.reset_index()
df.head()
# Out:
# C:\Users\hollyriver\AppData\Local\Temp\ipykernel_8884\712135142.py:12: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#      년도     시도   지역   건물동수       연면적  에너지사용량(TOE)/전기  에너지사용량(TOE)/도시가스  \
# 0  2018  Seoul  종로구  17929   9141777           64818             82015
# 1  2018  Seoul   중구  10598  10056233           81672             75260
# 2  2018  Seoul  용산구  17201  10639652           52659             85220
# 3  2018  Seoul  성동구  14180  11631770           60559            107416
# 4  2018  Seoul  광진구  21520  12054796           70609            130308
#
#    에너지사용량(TOE)/지역난방
# 0               111
# 1               563
# 2             12043
# 3                 0
# 4                 0

# %% [markdown]
# **데이터 정리**

# %%
df_energy = df.assign(시도 = df.시도.apply(lambda x : [v for k,v in {l['properties']['name_eng']:l['properties']['name'] for l in global_dict['features']}.items() if x == k].pop()))\
.assign(on = lambda _df : _df.시도 + '-' + _df.지역)

df_energy
# Out:
#        년도       시도    지역   건물동수       연면적  에너지사용량(TOE)/전기  에너지사용량(TOE)/도시가스  \
# 0    2018    서울특별시   종로구  17929   9141777           64818             82015
# 1    2018    서울특별시    중구  10598  10056233           81672             75260
# 2    2018    서울특별시   용산구  17201  10639652           52659             85220
# 3    2018    서울특별시   성동구  14180  11631770           60559            107416
# 4    2018    서울특별시   광진구  21520  12054796           70609            130308
# ..    ...      ...   ...    ...       ...             ...               ...
# 995  2019  제주특별자치도  서귀포시  34729   7233931           34641              1306
# 996  2020  제주특별자치도   제주시  66504  19819923           99212             22179
# 997  2020  제주특별자치도  서귀포시  34880   7330040           35510              1639
# 998  2021  제주특별자치도   제주시  67053  20275738          103217             25689
# 999  2021  제주특별자치도  서귀포시  35230   7512206           37884              2641
#
#      에너지사용량(TOE)/지역난방            on
# ...

# %%
df_global = pd.DataFrame([l['properties'] for l in global_dict['features']])
df_local = pd.DataFrame([l['properties'] for l in local_dict['features']])

# %%
df_json = df_local.assign(name = lambda _df : _df.name.apply(lambda x : x.split('시')[-1] if '시' in x and '구' in x and len(x) > 3 else x))\
.assign(on = lambda _df : _df.code.apply(lambda x : [v for k, v in {df_global.code[i]:df_global.name[i] for i in range(df_global.shape[0])}.items() if x[:2] == k].pop() + '-' + _df.name.loc[_df.code == x].to_list().pop()))\
.set_index('on').rename({'인천광역시-남구' : '인천광역시-미추홀구'}, axis = 0).reset_index().drop(['name', 'name_eng', 'base_year'], axis = 1)

df_json
# Out:
#                on   code
# 0       서울특별시-종로구  11010
# 1        서울특별시-중구  11020
# 2       서울특별시-용산구  11030
# 3       서울특별시-성동구  11040
# 4       서울특별시-광진구  11050
# ..            ...    ...
# 245      경상남도-함양군  38380
# 246      경상남도-거창군  38390
# 247      경상남도-합천군  38400
# 248   제주특별자치도-제주시  39010
# 249  제주특별자치도-서귀포시  39020
#
# [250 rows x 2 columns]

# %%
df_data = pd.merge(df_energy, df_json, on = 'on').drop('on', axis = 1); df_data
# Out:
#        년도       시도    지역   건물동수       연면적  에너지사용량(TOE)/전기  에너지사용량(TOE)/도시가스  \
# 0    2018    서울특별시   종로구  17929   9141777           64818             82015
# 1    2019    서울특별시   종로구  17851   9204140           63492             76653
# 2    2020    서울특별시   종로구  17638   9148895           60123             71263
# 3    2021    서울특별시   종로구  22845  18551145          125179            117061
# 4    2018    서울특별시    중구  10598  10056233           81672             75260
# ..    ...      ...   ...    ...       ...             ...               ...
# 995  2021  제주특별자치도   제주시  67053  20275738          103217             25689
# 996  2018  제주특별자치도  서귀포시  34154   6914685           34470              1597
# 997  2019  제주특별자치도  서귀포시  34729   7233931           34641              1306
# 998  2020  제주특별자치도  서귀포시  34880   7330040           35510              1639
# 999  2021  제주특별자치도  서귀포시  35230   7512206           37884              2641
#
#      에너지사용량(TOE)/지역난방   code
# ...

# %% [markdown]
# ## 문제
#
# **2018~2021년도 대전의 전기에너지 사용량을 애니메이션으로 시각화**

# %% [markdown]
# ### 풀이

# %%
[l['properties']['code'] for l in global_dict['features'] if '대전' in l['properties']['name']]
# Out:
# ['25']

# %%
daejeon_dict = local_dict.copy()
daejeon_dict['features'] = [l for l in local_dict['features'] if l['properties']['code'][:2] == '25']

# %%
px.choropleth_mapbox(
    geojson = daejeon_dict,
    featureidkey = 'properties.code',
    data_frame = df_data,
    locations = 'code',
    color = '에너지사용량(TOE)/전기',
    animation_frame = '년도',
    hover_data = ['시도', '지역'],
    ##---##
    mapbox_style="carto-positron",
    range_color = [0,400000],
    center={"lat": 36.3351, "lon": 127.3933},
    zoom=9,
    height=600,
    width=700,
)

# %%
fig.show()

# %%
df_data.loc[df_data.code.str[:2] == '25', ['년도','지역','에너지사용량(TOE)/전기']].sort_values(['지역', '년도'])
# Out:
#        년도   지역  에너지사용량(TOE)/전기
# 272  2018  대덕구           35885
# 273  2019  대덕구           34633
# 274  2020  대덕구           34043
# 275  2021  대덕구           34784
# 256  2018   동구           46291
# 257  2019   동구           44919
# 258  2020   동구           44121
# 259  2021   동구           44773
# 264  2018   서구           93242
# 265  2019   서구           91003
# 266  2020   서구           91113
# 267  2021   서구           93422
# 268  2018  유성구           81956
# 269  2019  유성구           81480
# 270  2020  유성구           81896
# 271  2021  유성구           85578
# 260  2018   중구           52286
# 261  2019   중구           50324
# 262  2020   중구           49811
# 263  2021   중구           49869

# %% [markdown]
# > 연도별 에너지 사용량에 거의 변함이 없어 색상이 눈에 띄게 바뀌지 않는다...
#
# **끝**
